# %%
# !pip install --upgrade pip -q
# !pip install -U unbabel-comet -q
# !pip install ctranslate2 -q
# !pip install datasets -q
# !!pip3 install faster-whisper -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 25.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 129.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 40.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 60.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 63.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 105.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 29.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 65.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 68.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 70.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 179.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.7/529.7 kB 21.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 4.25.6 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.6 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.6/38.6 MB 55.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# ['\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/1.1 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b1.1/1.1 MB\x1b \x1b25.9 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/35.2 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b \x1b35.1/35.2 MB\x1b \x1b263.5 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b\x1b╸\x1b \x1b35.1/35.2 MB\x1b \x1b263.5 MB/s\x1b eta \x1b0:00:01\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b35.2/35.2 MB\x1b \x1b67.6 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h\x1b[?25l   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b0.0/16.0 MB\x1b \x1b?\x1b eta \x1b-:--:--\x1b',
#  '\x1b[2K   \x1b━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━\x1b \x1b16.0/16.0 MB\x1b \x1b157.5 MB/s\x1b eta \x1b0:00:00\x1b',
#  '\x1b[?25h']

# %%
# !apt update
# !apt install libcudnn9-cuda-12
# !pip install nvidia-cublas-cu12 nvidia-cudnn-cu12==9.*

# !export LD_LIBRARY_PATH=`python3 -c 'import os; import nvidia.cublas.lib; import nvidia.cudnn.lib; print(os.path.dirname(nvidia.cublas.lib.__file__) + ":" + os.path.dirname(nvidia.cudnn.lib.__file__))'`
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,384 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,692 kB]
# Hit:10 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4,246 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:13 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:14 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,832 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,542 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,140 kB]
# Get:17 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,243 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,788 kB]
# Fetched 26.1 MB in 4s (7,382 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 36 packages can be upgraded. Run 'apt list --upgradable' to see them.
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libcudnn9-dev-cuda-12
# The following held packages will be changed:
#   libcudnn9-cuda-12
# The following packages will be upgraded:
#   libcudnn9-cuda-12 libcudnn9-dev-cuda-12
# 2 upgraded, 0 newly installed, 0 to remove and 34 not upgraded.
# E: Held packages were changed and -y was used without --allow-change-held-packages.
# Requirement already satisfied: nvidia-cublas-cu12 in /usr/local/lib/python3.11/dist-packages (12.4.5.8)
# Requirement already satisfied: nvidia-cudnn-cu12==9.* in /usr/local/lib/python3.11/dist-packages (9.1.0.70)

# %%
from datasets import load_dataset
import numpy as np

# %%
import os
cache_dir = "/content/huggingface_cache"
os.makedirs(cache_dir, exist_ok=True)

# Set ALL Hugging Face related cache directories
os.environ["TRANSFORMERS_CACHE"] = os.path.join(cache_dir, "transformers")
os.environ["HF_DATASETS_CACHE"] = os.path.join(cache_dir, "datasets")
os.environ["HF_HOME"] = os.path.join(cache_dir, "hf_home")
os.environ["HF_ASSETS_CACHE"] = os.path.join(cache_dir, "assets")
os.environ["HUGGINGFACE_HUB_CACHE"] = os.path.join(cache_dir, "hub")
os.environ["HF_MODULES_CACHE"] = os.path.join(cache_dir, "modules")

# Create all directories
for dir_path in [os.environ["TRANSFORMERS_CACHE"],
                os.environ["HF_DATASETS_CACHE"],
                os.environ["HF_HOME"],
                os.environ["HF_ASSETS_CACHE"],
                os.environ["HUGGINGFACE_HUB_CACHE"],
                os.environ["HF_MODULES_CACHE"]]:
    os.makedirs(dir_path, exist_ok=True)

# Force datasets to use the new cache
from datasets import config
config.HF_DATASETS_CACHE = os.environ["HF_DATASETS_CACHE"]

# %% [markdown]
# ### restart the machine after installing the unbabel-comet

# %% [markdown]
# # Transcription

# %%
dataset_name = "kreasof-ai/be-en-IWSLT2025"
test_dataset = load_dataset(dataset_name, trust_remote_code=True, split="test")
# Out:
# README.md:   0%|          | 0.00/620 [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/41 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/41 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/41 [00:00<?, ?files/s]
# train-00000-of-00041.parquet:   0%|          | 0.00/457M [00:00<?, ?B/s]
# train-00001-of-00041.parquet:   0%|          | 0.00/457M [00:00<?, ?B/s]
# train-00002-of-00041.parquet:   0%|          | 0.00/447M [00:00<?, ?B/s]
# train-00003-of-00041.parquet:   0%|          | 0.00/448M [00:00<?, ?B/s]
# train-00004-of-00041.parquet:   0%|          | 0.00/458M [00:00<?, ?B/s]
# train-00005-of-00041.parquet:   0%|          | 0.00/464M [00:00<?, ?B/s]
# train-00006-of-00041.parquet:   0%|          | 0.00/461M [00:00<?, ?B/s]
# train-00007-of-00041.parquet:   0%|          | 0.00/452M [00:00<?, ?B/s]
# train-00008-of-00041.parquet:   0%|          | 0.00/449M [00:00<?, ?B/s]
# train-00009-of-00041.parquet:   0%|          | 0.00/438M [00:00<?, ?B/s]
# train-00010-of-00041.parquet:   0%|          | 0.00/439M [00:00<?, ?B/s]
# train-00011-of-00041.parquet:   0%|          | 0.00/442M [00:00<?, ?B/s]
# train-00012-of-00041.parquet:   0%|          | 0.00/444M [00:00<?, ?B/s]
# train-00013-of-00041.parquet:   0%|          | 0.00/455M [00:00<?, ?B/s]
# train-00014-of-00041.parquet:   0%|          | 0.00/450M [00:00<?, ?B/s]
# train-00015-of-00041.parquet:   0%|          | 0.00/457M [00:00<?, ?B/s]
# train-00016-of-00041.parquet:   0%|          | 0.00/438M [00:00<?, ?B/s]
# train-00017-of-00041.parquet:   0%|          | 0.00/450M [00:00<?, ?B/s]
# train-00018-of-00041.parquet:   0%|          | 0.00/440M [00:00<?, ?B/s]
# train-00019-of-00041.parquet:   0%|          | 0.00/467M [00:00<?, ?B/s]
# train-00020-of-00041.parquet:   0%|          | 0.00/438M [00:00<?, ?B/s]
# train-00021-of-00041.parquet:   0%|          | 0.00/443M [00:00<?, ?B/s]
# train-00022-of-00041.parquet:   0%|          | 0.00/444M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-0d6486d06b8f> in <cell line: 0>()
#       1 dataset_name = "kreasof-ai/be-en-IWSLT2025"
# ----> 2 test_dataset = load_dataset(dataset_name, trust_remote_code=True, split="test")
#
# /usr/local/lib/python3.11/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2082
#    2083     # Download and prepare data
# -> 2084     builder_instance.download_and_prepare(
#    2085         download_config=download_config,
#    2086         download_mode=download_mode,
#
# /usr/local/lib/python3.11/dist-packages/datasets/builder.py in download_and_prepare(self, output_dir, download_config, download_mode, verification_mode, dl_manager, base_path, file_format, max_shard_size, num_proc, storage_options, **download_and_prepare_kwargs)
#     923                     if num_proc is not None:
#     924                         prepare_split_kwargs["num_proc"] = num_proc
# --> 925                     self._download_and_prepare(
#     926                         dl_manager=dl_manager,
#     927                         verification_mode=verification_mode,
#
# /usr/local/lib/python3.11/dist-packages/datasets/builder.py in _download_and_prepare(self, dl_manager, verification_mode, **prepare_split_kwargs)
#     977         split_dict = SplitDict(dataset_name=self.dataset_name)
#     978         split_generators_kwargs = self._make_split_generators_kwargs(prepare_split_kwargs)
# --> 979         split_generators = self._split_generators(dl_manager, **split_generators_kwargs)
#     980
#     981         # Checksums verification
#
# /usr/local/lib/python3.11/dist-packages/datasets/packaged_modules/parquet/parquet.py in _split_generators(self, dl_manager)
#      47             raise ValueError(f"At least one data file must be specified, but got data_files={self.config.data_files}")
#      48         dl_manager.download_config.extract_on_the_fly = True
# ---> 49         data_files = dl_manager.download_and_extract(self.config.data_files)
#      50         splits = []
#      51         for split_name, files in data_files.items():
#
# /usr/local/lib/python3.11/dist-packages/datasets/download/download_manager.py in download_and_extract(self, url_or_urls)
#     324             extracted_path(s): `str`, extracted paths of given URL(s).
#     325         """
# --> 326         return self.extract(self.download(url_or_urls))
#     327
#     328     def get_recorded_sizes_checksums(self):
#
# /usr/local/lib/python3.11/dist-packages/datasets/download/download_manager.py in download(self, url_or_urls)
#     157         start_time = datetime.now()
#     158         with stack_multiprocessing_download_progress_bars():
# --> 159             downloaded_path_or_paths = map_nested(
#     160                 download_func,
#     161                 url_or_urls,
#
# /usr/local/lib/python3.11/dist-packages/datasets/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, batched, batch_size, types, disable_tqdm, desc)
#     494         num_proc = 1
#     495     if any(isinstance(v, types) and len(v) > len(iterable) for v in iterable):
# --> 496         mapped = [
#     497             map_nested(
#     498                 function=function,
#
# /usr/local/lib/python3.11/dist-packages/datasets/utils/py_utils.py in <listcomp>(.0)
#     495     if any(isinstance(v, types) and len(v) > len(iterable) for v in iterable):
#     496         mapped = [
# --> 497             map_nested(
#     498                 function=function,
#     499                 data_struct=obj,
#
# /usr/local/lib/python3.11/dist-packages/datasets/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, parallel_min_length, batched, batch_size, types, disable_tqdm, desc)
#     511                 batch_size = max(len(iterable) // num_proc + int(len(iterable) % num_proc > 0), 1)
#     512             iterable = list(iter_batched(iterable, batch_size))
# --> 513         mapped = [
#     514             _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     515             for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#
# /usr/local/lib/python3.11/dist-packages/datasets/utils/py_utils.py in <listcomp>(.0)
#     512             iterable = list(iter_batched(iterable, batch_size))
#     513         mapped = [
# --> 514             _single_map_nested((function, obj, batched, batch_size, types, None, True, None))
#     515             for obj in hf_tqdm(iterable, disable=disable_tqdm, desc=desc)
#     516         ]
#
# /usr/local/lib/python3.11/dist-packages/datasets/utils/py_utils.py in _single_map_nested(args)
#     380         and all(not isinstance(v, (dict, types)) for v in data_struct)
#     381     ):
# --> 382         return [mapped_item for batch in iter_batched(data_struct, batch_size) for mapped_item in function(batch)]
#     383
#     384     # Reduce logging to keep things readable in multiprocessing with tqdm
#
# /usr/local/lib/python3.11/dist-packages/datasets/utils/py_utils.py in <listcomp>(.0)
#     380         and all(not isinstance(v, (dict, types)) for v in data_struct)
#     381     ):
# --> 382         return [mapped_item for batch in iter_batched(data_struct, batch_size) for mapped_item in function(batch)]
#     383
#     384     # Reduce logging to keep things readable in multiprocessing with tqdm
#
# /usr/local/lib/python3.11/dist-packages/datasets/download/download_manager.py in _download_batched(self, url_or_filenames, download_config)
#     204             )  # enable multithreading if files are small
#     205
# --> 206             return thread_map(
#     207                 download_func,
#     208                 url_or_filenames,
#
# /usr/local/lib/python3.11/dist-packages/tqdm/contrib/concurrent.py in thread_map(fn, *iterables, **tqdm_kwargs)
#      67     """
#      68     from concurrent.futures import ThreadPoolExecutor
# ---> 69     return _executor_map(ThreadPoolExecutor, fn, *iterables, **tqdm_kwargs)
#      70
#      71
#
# /usr/local/lib/python3.11/dist-packages/tqdm/contrib/concurrent.py in _executor_map(PoolExecutor, fn, *iterables, **tqdm_kwargs)
#      49         with PoolExecutor(max_workers=max_workers, initializer=tqdm_class.set_lock,
#      50                           initargs=(lk,)) as ex:
# ---> 51             return list(tqdm_class(ex.map(fn, *iterables, chunksize=chunksize), **kwargs))
#      52
#      53
#
# /usr/local/lib/python3.11/dist-packages/tqdm/notebook.py in __iter__(self)
#     248         try:
#     249             it = super().__iter__()
# --> 250             for obj in it:
#     251                 # return super(tqdm...) will not catch exception
#     252                 yield obj
#
# /usr/local/lib/python3.11/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result_iterator()
#     617                     # Careful not to keep a reference to the popped future
#     618                     if timeout is None:
# --> 619                         yield _result_or_cancel(fs.pop())
#     620                     else:
#     621                         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# /usr/lib/python3.11/concurrent/futures/_base.py in _result_or_cancel(***failed resolving arguments***)
#     315     try:
#     316         try:
# --> 317             return fut.result(timeout)
#     318         finally:
#     319             fut.cancel()
#
# /usr/lib/python3.11/concurrent/futures/_base.py in result(self, timeout)
#     449                     return self.__get_result()
#     450
# --> 451                 self._condition.wait(timeout)
#     452
#     453                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     325         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     326             if timeout is None:
# --> 327                 waiter.acquire()
#     328                 gotit = True
#     329             else:
#
# KeyboardInterrupt:

# %%
test_dataset

# %%
audio_arrays = [a["array"].astype(np.float32) for a in test_dataset["audio"]]

# %%
model_id = "kreasof-ai/whisper-medium-bem2en"
output_dir="ct2-whisper-medium-transcription-finetuned"
commit_hash= "2b91ce20bd264d43947d18db44d7d08e84ae49ee"

# !ct2-transformers-converter \
--model {model_id} \
--output_dir {output_dir} \
--revision {commit_hash} \
--quantization float16 \
--copy_files tokenizer_config.json\
--force

# %%
from faster_whisper import WhisperModel

model_name = output_dir

model = WhisperModel(model_name, device="cuda", compute_type="float16")

# %%
tgt_lang = "en"

transcriptions = []
segments, info = model.transcribe(audio_arrays[0],
                                beam_size=5,
                                language=tgt_lang,
                                vad_filter=True
                                )
transcription = " ".join([segment.text.strip() for segment in segments])
transcriptions.append(transcription)

# %%
from tqdm.auto import tqdm

tgt_lang = "en"

transcriptions = []

for audio_array in tqdm(audio_arrays, total=len(audio_arrays)):
    segments, info = model.transcribe(audio_array,
                                        beam_size=5,
                                        language=tgt_lang,
                                        vad_filter=True)
    transcription = " ".join([segment.text.strip() for segment in segments])
    transcriptions.append(transcription)

# %%
source_sentences = transcriptions

# %% [markdown]
# # Translation

# %%
# mt_model_name = "kreasof-ai/nllb-200-distilled-600M-bem2en-flores200"
# output_mt = "ct2-nllb-be-en-finetuned"
# commit_hash = "3dc4fe6449ec5ac06e45fcebc26e5221c6a8d7f5"
# !ct2-transformers-converter --model {mt_model_name} --revision {commit_hash} --quantization float16 --output_dir {output_mt} --force
# Out:
# config.json: 100% 804/804 [00:00<00:00, 6.35MB/s]
# 2025-04-17 02:39:25.341495: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744857565.617453    2737 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744857565.688147    2737 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-17 02:39:26.189914: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# model.safetensors.index.json: 100% 89.8k/89.8k [00:00<00:00, 7.42MB/s]
# Fetching 3 files:   0% 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0% 0.00/4.99G [00:00<?, ?B/s]
#
# model-00002-of-00003.safetensors:   0% 0.00/4.99G [00:00<?, ?B/s]
#
# model-00002-of-00003.safetensors:   0% 10.5M/4.99G [00:00<01:16, 65.4MB/s]
# model-00001-of-00003.safetensors:   0% 10.5M/4.99G [00:00<01:32, 53.7MB/s]
#
# model-00002-of-00003.safetensors:   0% 21.0M/4.99G [00:00<01:00, 81.6MB/s]
# model-00001-of-00003.safetensors:   0% 21.0M/4.99G [00:00<01:17, 64.2MB/s]
#
# model-00002-of-00003.safetensors:   1% 31.5M/4.99G [00:00<01:00, 81.7MB/s]
#
#
# model-00003-of-00003.safetensors:   0% 0.00/3.41G [00:00<?, ?B/s]
# model-00001-of-00003.safetensors:   1% 31.5M/4.99G [00:00<01:14, 66.3MB/s]
#
# model-00002-of-00003.safetensors:   1% 41.9M/4.99G [00:00<00:59, 83.0MB/s]
#
#
# model-00003-of-00003.safetensors:   0% 10.5M/3.41G [00:00<00:48, 70.3MB/s]
# model-00001-of-00003.safetensors:   1% 41.9M/4.99G [00:00<01:08, 72.6MB/s]
#
# model-00002-of-00003.safetensors:   1% 52.4M/4.99G [00:00<01:00, 81.3MB/s]
#
#
# model-00003-of-00003.safetensors:   1% 21.0M/3.41G [00:00<00:46, 73.0MB/s]
# model-00001-of-00003.safetensors:   1% 52.4M/4.99G [00:00<01:04, 76.3MB/s]
#
# model-00002-of-00003.safetensors:   1% 62.9M/4.99G [00:00<00:59, 82.6MB/s]
#
#
# model-00003-of-00003.safetensors:   1% 31.5M/3.41G [00:00<00:41, 81.9MB/s]
# model-00001-of-00003.safetensors:   1% 62.9M/4.99G [00:00<01:01, 79.6MB/s]
#
# model-00002-of-00003.safetensors:   1% 73.4M/4.99G [00:00<00:59, 82.4MB/s]
#
#
# model-00003-of-00003.safetensors:   1% 41.9M/3.41G [00:00<00:41, 80.2MB/s]
# model-00001-of-00003.safetensors:   1% 73.4M/4.99G [00:00<01:01, 80.0MB/s]
#
# model-00002-of-00003.safetensors:   2% 83.9M/4.99G [00:01<01:00, 81.6MB/s]
#
#
# model-00003-of-00003.safetensors:   2% 52.4M/3.41G [00:00<00:41, 80.3MB/s]
# model-00001-of-00003.safetensors:   2% 83.9M/4.99G [00:01<01:06, 73.3MB/s]
#
# model-00002-of-00003.safetensors:   2% 94.4M/4.99G [00:01<01:00, 81.1MB/s]
#
#
# model-00003-of-00003.safetensors:   2% 62.9M/3.41G [00:00<00:42, 79.3MB/s]
# model-00001-of-00003.safetensors:   2% 94.4M/4.99G [00:01<01:00, 80.8MB/s]
#
# model-00002-of-00003.safetensors:   2% 105M/4.99G [00:01<00:59, 82.2MB/s]
#
#
# model-00003-of-00003.safetensors:   2% 73.4M/3.41G [00:00<00:41, 80.5MB/s]
#
# model-00002-of-00003.safetensors:   2% 115M/4.99G [00:01<00:59, 82.2MB/s]
# model-00001-of-00003.safetensors:   2% 115M/4.99G [00:01<00:55, 88.5MB/s]
#
#
# model-00003-of-00003.safetensors:   2% 83.9M/3.41G [00:01<00:41, 80.2MB/s]
#
# model-00002-of-00003.safetensors:   3% 126M/4.99G [00:01<00:59, 82.1MB/s]
# model-00001-of-00003.safetensors:   3% 126M/4.99G [00:01<00:55, 87.1MB/s]
#
#
# model-00003-of-00003.safetensors:   3% 94.4M/3.41G [00:01<00:42, 78.4MB/s]
#
# model-00002-of-00003.safetensors:   3% 136M/4.99G [00:01<00:59, 81.9MB/s]
# model-00001-of-00003.safetensors:   3% 136M/4.99G [00:01<00:55, 87.2MB/s]
#
#
# model-00003-of-00003.safetensors:   3% 105M/3.41G [00:01<00:41, 79.4MB/s]
#
# model-00002-of-00003.safetensors:   3% 147M/4.99G [00:01<00:59, 81.5MB/s]
# model-00001-of-00003.safetensors:   3% 147M/4.99G [00:01<00:55, 87.0MB/s]
#
#
# model-00003-of-00003.safetensors:   3% 115M/3.41G [00:01<00:41, 79.9MB/s]
#
# model-00002-of-00003.safetensors:   3% 157M/4.99G [00:01<01:00, 80.1MB/s]
# model-00001-of-00003.safetensors:   3% 157M/4.99G [00:01<00:56, 85.0MB/s]
#
#
# model-00003-of-00003.safetensors:   4% 126M/3.41G [00:01<00:41, 79.7MB/s]
#
# model-00002-of-00003.safetensors:   3% 168M/4.99G [00:02<00:58, 82.2MB/s]
# model-00001-of-00003.safetensors:   3% 168M/4.99G [00:02<00:56, 85.5MB/s]
#
#
# model-00003-of-00003.safetensors:   4% 136M/3.41G [00:01<00:41, 79.7MB/s]
#
# model-00002-of-00003.safetensors:   4% 178M/4.99G [00:02<00:58, 82.1MB/s]
# model-00001-of-00003.safetensors:   4% 178M/4.99G [00:02<00:56, 85.3MB/s]
#
#
# model-00003-of-00003.safetensors:   4% 147M/3.41G [00:01<00:41, 79.5MB/s]
#
# model-00002-of-00003.safetensors:   4% 189M/4.99G [00:02<00:58, 81.7MB/s]
# model-00001-of-00003.safetensors:   4% 189M/4.99G [00:02<00:56, 85.5MB/s]
#
#
# model-00003-of-00003.safetensors:   5% 157M/3.41G [00:01<00:41, 78.7MB/s]
# model-00001-of-00003.safetensors:   4% 199M/4.99G [00:02<00:55, 86.1MB/s]
#
# model-00002-of-00003.safetensors:   4% 199M/4.99G [00:02<00:58, 81.3MB/s]
#
#
# model-00003-of-00003.safetensors:   5% 168M/3.41G [00:02<00:40, 79.8MB/s]
# model-00001-of-00003.safetensors:   4% 210M/4.99G [00:02<00:55, 86.0MB/s]
#
# model-00002-of-00003.safetensors:   4% 210M/4.99G [00:02<00:58, 81.5MB/s]
#
#
# model-00003-of-00003.safetensors:   5% 178M/3.41G [00:02<00:40, 80.0MB/s]
# model-00001-of-00003.safetensors:   4% 220M/4.99G [00:02<00:55, 86.0MB/s]
#
# model-00002-of-00003.safetensors:   4% 220M/4.99G [00:02<00:58, 81.3MB/s]
#
#
# model-00003-of-00003.safetensors:   6% 189M/3.41G [00:02<00:40, 79.9MB/s]
# model-00001-of-00003.safetensors:   5% 231M/4.99G [00:02<00:55, 85.4MB/s]
#
# model-00002-of-00003.safetensors:   5% 231M/4.99G [00:02<01:00, 78.6MB/s]
#
#
# model-00003-of-00003.safetensors:   6% 199M/3.41G [00:02<00:40, 79.0MB/s]
# model-00001-of-00003.safetensors:   5% 241M/4.99G [00:02<00:55, 85.1MB/s]
#
# model-00002-of-00003.safetensors:   5% 241M/4.99G [00:02<00:57, 82.6MB/s]
#
#
# model-00003-of-00003.safetensors:   6% 210M/3.41G [00:02<00:40, 79.2MB/s]
# model-00001-of-00003.safetensors:   5% 252M/4.99G [00:03<00:55, 85.6MB/s]
#
# model-00002-of-00003.safetensors:   5% 252M/4.99G [00:03<00:57, 82.5MB/s]
# model-00001-of-00003.safetensors:   5% 262M/4.99G [00:03<00:55, 85.3MB/s]
#
#
# model-00003-of-00003.safetensors:   6% 220M/3.41G [00:02<00:40, 78.7MB/s]
#
# model-00002-of-00003.safetensors:   5% 262M/4.99G [00:03<00:57, 82.1MB/s]
# model-00001-of-00003.safetensors:   5% 273M/4.99G [00:03<00:55, 85.3MB/s]
#
#
# model-00003-of-00003.safetensors:   7% 231M/3.41G [00:02<00:40, 78.1MB/s]
#
# model-00002-of-00003.safetensors:   5% 273M/4.99G [00:03<01:01, 76.6MB/s]
# model-00001-of-00003.safetensors:   6% 283M/4.99G [00:03<00:55, 84.0MB/s]
#
#
# model-00003-of-00003.safetensors:   7% 241M/3.41G [00:03<00:41, 76.7MB/s]
#
# model-00002-of-00003.safetensors:   6% 283M/4.99G [00:03<01:02, 75.5MB/s]
# model-00001-of-00003.safetensors:   6% 294M/4.99G [00:03<01:01, 76.6MB/s]
#
#
# model-00003-of-00003.safetensors:   7% 252M/3.41G [00:03<00:42, 75.1MB/s]
#
# model-00002-of-00003.safetensors:   6% 294M/4.99G [00:03<01:03, 74.2MB/s]
#
#
# model-00003-of-00003.safetensors:   8% 262M/3.41G [00:03<00:39, 80.6MB/s]
# model-00001-of-00003.safetensors:   6% 304M/4.99G [00:03<01:03, 73.4MB/s]
#
# model-00002-of-00003.safetensors:   6% 304M/4.99G [00:03<00:59, 78.8MB/s]
#
#
# model-00003-of-00003.safetensors:   8% 273M/3.41G [00:03<00:38, 82.4MB/s]
# model-00001-of-00003.safetensors:   6% 315M/4.99G [00:03<01:05, 70.8MB/s]
#
# model-00002-of-00003.safetensors:   6% 315M/4.99G [00:03<01:01, 76.4MB/s]
#
#
# model-00003-of-00003.safetensors:   8% 283M/3.41G [00:03<00:43, 72.0MB/s]
#
# model-00002-of-00003.safetensors:   7% 325M/4.99G [00:04<00:59, 77.7MB/s]
# model-00001-of-00003.safetensors:   7% 336M/4.99G [00:04<00:56, 83.0MB/s]
#
#
# model-00003-of-00003.safetensors:   9% 294M/3.41G [00:03<00:41, 74.7MB/s]
# model-00001-of-00003.safetensors:   7% 346M/4.99G [00:04<00:53, 86.8MB/s]
#
# model-00002-of-00003.safetensors:   7% 346M/4.99G [00:04<00:52, 87.8MB/s]
#
#
# model-00003-of-00003.safetensors:   9% 304M/3.41G [00:03<00:41, 75.7MB/s]
#
# model-00002-of-00003.safetensors:   7% 357M/4.99G [00:04<00:56, 82.1MB/s]
#
#
# model-00003-of-00003.safetensors:   9% 315M/3.41G [00:04<00:41, 74.1MB/s]
# model-00001-of-00003.safetensors:   7% 367M/4.99G [00:04<00:52, 87.6MB/s]
#
#
# model-00003-of-00003.safetensors:  10% 325M/3.41G [00:04<00:39, 78.4MB/s]
#
# model-00002-of-00003.safetensors:   8% 377M/4.99G [00:04<00:52, 87.5MB/s]
# model-00001-of-00003.safetensors:   8% 388M/4.99G [00:04<00:49, 93.1MB/s]
#
#
# model-00003-of-00003.safetensors:  10% 336M/3.41G [00:04<00:36, 83.1MB/s]
#
# model-00002-of-00003.safetensors:   8% 388M/4.99G [00:04<00:55, 82.3MB/s]
#
#
# model-00003-of-00003.safetensors:  10% 346M/3.41G [00:04<00:40, 74.8MB/s]
# model-00001-of-00003.safetensors:   8% 398M/4.99G [00:04<00:55, 82.8MB/s]
#
# model-00002-of-00003.safetensors:   8% 398M/4.99G [00:04<00:59, 76.7MB/s]
#
#
# model-00003-of-00003.safetensors:  10% 357M/3.41G [00:04<00:39, 76.8MB/s]
# model-00001-of-00003.safetensors:   8% 409M/4.99G [00:05<01:10, 64.6MB/s]
#
# model-00002-of-00003.safetensors:   8% 419M/4.99G [00:05<00:53, 85.6MB/s]
#
#
# model-00003-of-00003.safetensors:  11% 377M/3.41G [00:04<00:36, 82.7MB/s]
# model-00001-of-00003.safetensors:   8% 419M/4.99G [00:05<01:07, 68.0MB/s]
#
# model-00002-of-00003.safetensors:   9% 430M/4.99G [00:05<00:53, 85.6MB/s]
#
#
# model-00003-of-00003.safetensors:  11% 388M/3.41G [00:04<00:37, 80.9MB/s]
#
# model-00002-of-00003.safetensors:   9% 440M/4.99G [00:05<00:54, 83.9MB/s]
# model-00001-of-00003.safetensors:   9% 440M/4.99G [00:05<00:57, 79.1MB/s]
#
#
# model-00003-of-00003.safetensors:  12% 398M/3.41G [00:05<00:36, 81.5MB/s]
#
# model-00002-of-00003.safetensors:   9% 451M/4.99G [00:05<00:55, 82.4MB/s]
# model-00001-of-00003.safetensors:   9% 451M/4.99G [00:05<00:54, 82.7MB/s]
#
#
# model-00003-of-00003.safetensors:  12% 409M/3.41G [00:05<00:37, 80.8MB/s]
#
# model-00002-of-00003.safetensors:   9% 461M/4.99G [00:05<00:55, 82.2MB/s]
# model-00001-of-00003.safetensors:   9% 472M/4.99G [00:05<00:46, 96.6MB/s]
#
#
# model-00003-of-00003.safetensors:  12% 419M/3.41G [00:05<00:38, 76.9MB/s]
#
# model-00002-of-00003.safetensors:   9% 472M/4.99G [00:05<00:53, 84.4MB/s]
# model-00001-of-00003.safetensors:  10% 482M/4.99G [00:05<00:46, 97.0MB/s]
#
#
# model-00003-of-00003.safetensors:  13% 430M/3.41G [00:05<00:37, 79.6MB/s]
#
# model-00002-of-00003.safetensors:  10% 482M/4.99G [00:05<00:56, 79.2MB/s]
# model-00001-of-00003.safetensors:  10% 493M/4.99G [00:05<00:50, 88.7MB/s]
#
#
# model-00003-of-00003.safetensors:  13% 440M/3.41G [00:05<00:38, 76.8MB/s]
#
# model-00002-of-00003.safetensors:  10% 493M/4.99G [00:06<00:56, 79.2MB/s]
# model-00001-of-00003.safetensors:  10% 503M/4.99G [00:06<00:49, 89.8MB/s]
#
#
# model-00003-of-00003.safetensors:  13% 451M/3.41G [00:05<00:37, 79.5MB/s]
#
# model-00002-of-00003.safetensors:  10% 503M/4.99G [00:06<00:57, 78.1MB/s]
# model-00001-of-00003.safetensors:  10% 514M/4.99G [00:06<00:52, 86.0MB/s]
#
# model-00002-of-00003.safetensors:  10% 514M/4.99G [00:06<00:55, 80.0MB/s]
#
# model-00002-of-00003.safetensors:  11% 524M/4.99G [00:06<00:55, 80.5MB/s]
#
# model-00002-of-00003.safetensors:  11% 535M/4.99G [00:06<00:55, 80.7MB/s]
#
# model-00002-of-00003.safetensors:  11% 545M/4.99G [00:06<00:54, 81.1MB/s]
#
# model-00002-of-00003.safetensors:  11% 556M/4.99G [00:06<00:54, 81.2MB/s]
#
# model-00002-of-00003.safetensors:  11% 566M/4.99G [00:06<00:54, 81.2MB/s]
#
# model-00002-of-00003.safetensors:  12% 577M/4.99G [00:07<00:54, 81.3MB/s]
#
# model-00002-of-00003.safetensors:  12% 587M/4.99G [00:07<00:54, 80.9MB/s]
#
# model-00002-of-00003.safetensors:  12% 598M/4.99G [00:07<00:53, 81.3MB/s]
#
# model-00002-of-00003.safetensors:  12% 608M/4.99G [00:07<00:53, 81.6MB/s]
# model-00001-of-00003.safetensors:  11% 524M/4.99G [00:07<03:10, 23.5MB/s]
#
#
# model-00003-of-00003.safetensors:  14% 461M/3.41G [00:07<02:23, 20.6MB/s]
#
# model-00002-of-00003.safetensors:  12% 619M/4.99G [00:07<00:53, 81.5MB/s]
# model-00001-of-00003.safetensors:  11% 545M/4.99G [00:07<01:58, 37.4MB/s]
#
#
# model-00003-of-00003.safetensors:  14% 472M/3.41G [00:07<01:51, 26.3MB/s]
#
# model-00002-of-00003.safetensors:  13% 629M/4.99G [00:07<00:53, 81.4MB/s]
# model-00001-of-00003.safetensors:  11% 556M/4.99G [00:07<01:44, 42.6MB/s]
#
#
# model-00003-of-00003.safetensors:  14% 482M/3.41G [00:07<01:31, 32.1MB/s]
#
# model-00002-of-00003.safetensors:  13% 640M/4.99G [00:07<00:53, 81.5MB/s]
#
#
# model-00003-of-00003.safetensors:  14% 493M/3.41G [00:07<01:12, 40.3MB/s]
# model-00001-of-00003.safetensors:  12% 577M/4.99G [00:07<01:16, 57.9MB/s]
#
# model-00002-of-00003.safetensors:  13% 650M/4.99G [00:08<00:53, 81.7MB/s]
#
#
# model-00003-of-00003.safetensors:  15% 503M/3.41G [00:07<00:59, 49.0MB/s]
# model-00001-of-00003.safetensors:  12% 598M/4.99G [00:08<00:58, 75.1MB/s]
#
# model-00002-of-00003.safetensors:  13% 661M/4.99G [00:08<00:53, 80.6MB/s]
#
#
# model-00003-of-00003.safetensors:  15% 524M/3.41G [00:07<00:40, 71.0MB/s]
# model-00001-of-00003.safetensors:  12% 619M/4.99G [00:08<00:45, 95.9MB/s]
#
# model-00002-of-00003.safetensors:  13% 671M/4.99G [00:08<00:52, 81.9MB/s]
#
#
# model-00003-of-00003.safetensors:  16% 545M/3.41G [00:07<00:32, 88.0MB/s]
# model-00001-of-00003.safetensors:  13% 640M/4.99G [00:08<00:39, 110MB/s]
#
# model-00002-of-00003.safetensors:  14% 682M/4.99G [00:08<00:52, 82.1MB/s]
#
#
# model-00003-of-00003.safetensors:  17% 566M/3.41G [00:08<00:27, 104MB/s]
#
# model-00002-of-00003.safetensors:  14% 692M/4.99G [00:08<00:52, 81.4MB/s]
# model-00001-of-00003.safetensors:  13% 661M/4.99G [00:08<00:42, 102MB/s]
#
# model-00002-of-00003.safetensors:  14% 703M/4.99G [00:08<00:53, 80.5MB/s]
#
#
# model-00003-of-00003.safetensors:  17% 587M/3.41G [00:08<00:28, 99.3MB/s]
#
# model-00002-of-00003.safetensors:  14% 713M/4.99G [00:08<00:52, 81.7MB/s]
# model-00001-of-00003.safetensors:  14% 682M/4.99G [00:08<00:44, 96.9MB/s]
#
# model-00002-of-00003.safetensors:  15% 724M/4.99G [00:08<00:52, 81.8MB/s]
#
#
# model-00003-of-00003.safetensors:  18% 608M/3.41G [00:08<00:31, 88.7MB/s]
#
# model-00002-of-00003.safetensors:  15% 734M/4.99G [00:09<00:51, 82.0MB/s]
# model-00001-of-00003.safetensors:  14% 703M/4.99G [00:09<00:46, 92.8MB/s]
#
#
# model-00003-of-00003.safetensors:  18% 619M/3.41G [00:08<00:31, 88.6MB/s]
#
# model-00002-of-00003.safetensors:  15% 744M/4.99G [00:09<00:51, 81.9MB/s]
#
#
# model-00003-of-00003.safetensors:  18% 629M/3.41G [00:08<00:32, 84.7MB/s]
#
# model-00002-of-00003.safetensors:  15% 755M/4.99G [00:09<00:53, 79.8MB/s]
# model-00001-of-00003.safetensors:  15% 724M/4.99G [00:09<00:47, 89.8MB/s]
#
# model-00002-of-00003.safetensors:  15% 765M/4.99G [00:09<00:51, 82.4MB/s]
#
#
# model-00003-of-00003.safetensors:  19% 640M/3.41G [00:11<03:04, 15.0MB/s]
# model-00001-of-00003.safetensors:  15% 734M/4.99G [00:11<03:43, 19.0MB/s]
#
# model-00002-of-00003.safetensors:  16% 776M/4.99G [00:11<05:31, 12.7MB/s]
#
#
# model-00003-of-00003.safetensors:  19% 650M/3.41G [00:11<02:36, 17.7MB/s]
# model-00001-of-00003.safetensors:  15% 744M/4.99G [00:13<04:57, 14.3MB/s]
#
# model-00002-of-00003.safetensors:  16% 786M/4.99G [00:17<14:21, 4.88MB/s]
#
#
# model-00003-of-00003.safetensors:  19% 661M/3.41G [00:17<08:38, 5.30MB/s]
#
# model-00002-of-00003.safetensors:  16% 797M/4.99G [00:18<11:48, 5.91MB/s]
#
#
# model-00003-of-00003.safetensors:  20% 682M/3.41G [00:17<05:00, 9.06MB/s]
#
# model-00002-of-00003.safetensors:  16% 818M/4.99G [00:18<06:32, 10.6MB/s]
# model-00001-of-00003.safetensors:  15% 755M/4.99G [00:18<11:14, 6.27MB/s]
#
#
# model-00003-of-00003.safetensors:  21% 703M/3.41G [00:17<03:12, 14.1MB/s]
# model-00001-of-00003.safetensors:  16% 776M/4.99G [00:18<07:01, 9.98MB/s]
#
# model-00002-of-00003.safetensors:  17% 839M/4.99G [00:18<04:12, 16.4MB/s]
# model-00001-of-00003.safetensors:  16% 797M/4.99G [00:18<04:41, 14.9MB/s]
#
#
# model-00003-of-00003.safetensors:  21% 724M/3.41G [00:18<02:16, 19.6MB/s]
#
# model-00002-of-00003.safetensors:  17% 860M/4.99G [00:18<02:54, 23.7MB/s]
# model-00001-of-00003.safetensors:  16% 807M/4.99G [00:18<03:55, 17.7MB/s]
#
# model-00002-of-00003.safetensors:  17% 870M/4.99G [00:18<02:32, 27.1MB/s]
#
#
# model-00003-of-00003.safetensors:  22% 744M/3.41G [00:18<01:39, 26.8MB/s]
# model-00001-of-00003.safetensors:  17% 828M/4.99G [00:19<03:46, 18.3MB/s]
#
#
# model-00003-of-00003.safetensors:  22% 765M/3.41G [00:21<03:22, 13.1MB/s]
# model-00001-of-00003.safetensors:  17% 839M/4.99G [00:22<06:10, 11.2MB/s]
#
# model-00002-of-00003.safetensors:  18% 891M/4.99G [00:22<05:38, 12.1MB/s]
# model-00001-of-00003.safetensors:  17% 860M/4.99G [00:22<03:59, 17.2MB/s]
#
#
# model-00003-of-00003.safetensors:  23% 786M/3.41G [00:21<02:23, 18.3MB/s]
#
# model-00002-of-00003.safetensors:  18% 912M/4.99G [00:22<03:50, 17.7MB/s]
#
# model-00002-of-00003.safetensors:  19% 923M/4.99G [00:22<03:12, 21.1MB/s]
# model-00001-of-00003.safetensors:  18% 891M/4.99G [00:22<02:25, 28.1MB/s]
#
#
# model-00003-of-00003.safetensors:  24% 807M/3.41G [00:22<01:46, 24.4MB/s]
#
# model-00002-of-00003.safetensors:  19% 933M/4.99G [00:22<02:41, 25.0MB/s]
# model-00001-of-00003.safetensors:  18% 902M/4.99G [00:22<02:10, 31.4MB/s]
#
#
# model-00003-of-00003.safetensors:  24% 818M/3.41G [00:22<01:34, 27.5MB/s]
#
# model-00002-of-00003.safetensors:  19% 954M/4.99G [00:22<01:57, 34.4MB/s]
#
#
# model-00003-of-00003.safetensors:  24% 828M/3.41G [00:22<01:26, 29.8MB/s]
# model-00001-of-00003.safetensors:  19% 923M/4.99G [00:22<01:47, 37.6MB/s]
#
# model-00002-of-00003.safetensors:  19% 965M/4.99G [00:22<01:47, 37.4MB/s]
#
#
# model-00003-of-00003.safetensors:  25% 839M/3.41G [00:22<01:14, 34.6MB/s]
# model-00001-of-00003.safetensors:  19% 933M/4.99G [00:23<01:37, 41.5MB/s]
#
# model-00002-of-00003.safetensors:  20% 975M/4.99G [00:23<01:33, 43.1MB/s]
#
#
# model-00003-of-00003.safetensors:  25% 849M/3.41G [00:22<01:03, 40.3MB/s]
# model-00001-of-00003.safetensors:  19% 944M/4.99G [00:23<01:26, 46.7MB/s]
#
# model-00002-of-00003.safetensors:  20% 986M/4.99G [00:23<01:23, 48.1MB/s]
#
#
# model-00003-of-00003.safetensors:  25% 860M/3.41G [00:22<00:53, 47.4MB/s]
# model-00001-of-00003.safetensors:  19% 965M/4.99G [00:23<01:02, 64.1MB/s]
#
# model-00002-of-00003.safetensors:  20% 1.01G/4.99G [00:23<01:01, 64.9MB/s]
#
#
# model-00003-of-00003.safetensors:  26% 881M/3.41G [00:23<00:39, 63.7MB/s]
# model-00001-of-00003.safetensors:  20% 986M/4.99G [00:23<00:47, 83.4MB/s]
#
# model-00002-of-00003.safetensors:  20% 1.02G/4.99G [00:23<00:56, 69.9MB/s]
#
# model-00002-of-00003.safetensors:  21% 1.03G/4.99G [00:23<01:12, 54.3MB/s]
#
#
# model-00003-of-00003.safetensors:  26% 902M/3.41G [00:23<00:43, 58.2MB/s]
# model-00001-of-00003.safetensors:  20% 1.01G/4.99G [00:23<00:58, 67.7MB/s]
#
#
# model-00003-of-00003.safetensors:  27% 912M/3.41G [00:23<00:42, 59.3MB/s]
#
# model-00002-of-00003.safetensors:  21% 1.04G/4.99G [00:23<01:11, 55.6MB/s]
#
#
# model-00003-of-00003.safetensors:  27% 923M/3.41G [00:27<04:19, 9.56MB/s]
# model-00001-of-00003.safetensors:  21% 1.03G/4.99G [00:28<05:06, 12.9MB/s]
#
# model-00002-of-00003.safetensors:  21% 1.05G/4.99G [00:28<08:04, 8.12MB/s]
#
#
# model-00003-of-00003.safetensors:  27% 933M/3.41G [00:27<03:24, 12.1MB/s]
#
# model-00002-of-00003.safetensors:  21% 1.06G/4.99G [00:28<06:00, 10.9MB/s]
# model-00001-of-00003.safetensors:  21% 1.05G/4.99G [00:28<03:40, 17.9MB/s]
#
# model-00002-of-00003.safetensors:  21% 1.07G/4.99G [00:28<04:29, 14.5MB/s]
#
#
# model-00003-of-00003.safetensors:  28% 954M/3.41G [00:28<02:08, 19.1MB/s]
#
#
# model-00003-of-00003.safetensors:  28% 965M/3.41G [00:28<01:44, 23.4MB/s]
#
# model-00002-of-00003.safetensors:  22% 1.08G/4.99G [00:28<03:25, 19.0MB/s]
# model-00001-of-00003.safetensors:  21% 1.06G/4.99G [00:28<03:21, 19.5MB/s]
#
# model-00002-of-00003.safetensors:  22% 1.09G/4.99G [00:28<02:42, 23.9MB/s]
#
#
# model-00003-of-00003.safetensors:  29% 986M/3.41G [00:28<01:13, 32.8MB/s]
# model-00001-of-00003.safetensors:  21% 1.07G/4.99G [00:28<02:48, 23.3MB/s]
#
# model-00002-of-00003.safetensors:  22% 1.10G/4.99G [00:28<02:09, 30.0MB/s]
#
#
# model-00003-of-00003.safetensors:  29% 996M/3.41G [00:28<01:02, 38.5MB/s]
# model-00001-of-00003.safetensors:  22% 1.09G/4.99G [00:29<01:55, 33.7MB/s]
#
# model-00002-of-00003.safetensors:  22% 1.11G/4.99G [00:29<01:46, 36.5MB/s]
#
#
# model-00003-of-00003.safetensors:  30% 1.01G/3.41G [00:28<00:54, 44.0MB/s]
# model-00001-of-00003.safetensors:  22% 1.10G/4.99G [00:29<01:41, 38.3MB/s]
#
# model-00002-of-00003.safetensors:  23% 1.12G/4.99G [00:29<01:29, 43.4MB/s]
#
#
# model-00003-of-00003.safetensors:  30% 1.02G/3.41G [00:28<00:47, 50.1MB/s]
# model-00001-of-00003.safetensors:  22% 1.11G/4.99G [00:29<01:29, 43.1MB/s]
#
# model-00002-of-00003.safetensors:  23% 1.13G/4.99G [00:29<01:17, 50.0MB/s]
#
#
# model-00003-of-00003.safetensors:  30% 1.03G/3.41G [00:28<00:43, 54.9MB/s]
#
# model-00002-of-00003.safetensors:  23% 1.14G/4.99G [00:29<01:06, 58.1MB/s]
#
#
# model-00003-of-00003.safetensors:  30% 1.04G/3.41G [00:29<00:37, 62.5MB/s]
# model-00001-of-00003.safetensors:  23% 1.13G/4.99G [00:29<01:08, 56.0MB/s]
#
# model-00002-of-00003.safetensors:  23% 1.15G/4.99G [00:29<00:57, 66.4MB/s]
#
#
# model-00003-of-00003.safetensors:  31% 1.05G/3.41G [00:29<00:33, 69.8MB/s]
# model-00001-of-00003.safetensors:  23% 1.14G/4.99G [00:29<01:01, 62.4MB/s]
#
# model-00002-of-00003.safetensors:  23% 1.16G/4.99G [00:29<00:53, 71.5MB/s]
#
#
# model-00003-of-00003.safetensors:  31% 1.06G/3.41G [00:29<00:31, 75.3MB/s]
# model-00001-of-00003.safetensors:  23% 1.15G/4.99G [00:29<01:01, 61.9MB/s]
#
#
# model-00003-of-00003.safetensors:  31% 1.07G/3.41G [00:29<00:29, 79.9MB/s]
#
# model-00002-of-00003.safetensors:  24% 1.17G/4.99G [00:29<00:54, 69.4MB/s]
#
#
# model-00003-of-00003.safetensors:  32% 1.08G/3.41G [00:29<00:28, 82.4MB/s]
# model-00001-of-00003.safetensors:  23% 1.16G/4.99G [00:29<01:01, 62.2MB/s]
#
# model-00002-of-00003.safetensors:  24% 1.18G/4.99G [00:29<00:57, 65.6MB/s]
#
#
# model-00003-of-00003.safetensors:  32% 1.09G/3.41G [00:29<00:26, 87.2MB/s]
# model-00001-of-00003.safetensors:  24% 1.17G/4.99G [00:30<00:55, 69.2MB/s]
#
#
# model-00003-of-00003.safetensors:  32% 1.10G/3.41G [00:29<00:26, 88.0MB/s]
# model-00001-of-00003.safetensors:  24% 1.18G/4.99G [00:30<00:54, 70.3MB/s]
#
# model-00002-of-00003.safetensors:  24% 1.21G/4.99G [00:30<00:47, 79.6MB/s]
#
#
# model-00003-of-00003.safetensors:  33% 1.11G/3.41G [00:29<00:27, 82.1MB/s]
# model-00001-of-00003.safetensors:  24% 1.20G/4.99G [00:30<00:50, 74.4MB/s]
#
# model-00002-of-00003.safetensors:  24% 1.22G/4.99G [00:30<00:48, 77.8MB/s]
#
#
# model-00003-of-00003.safetensors:  33% 1.12G/3.41G [00:29<00:27, 83.4MB/s]
# model-00001-of-00003.safetensors:  24% 1.21G/4.99G [00:30<00:47, 79.3MB/s]
#
# model-00002-of-00003.safetensors:  25% 1.23G/4.99G [00:30<00:47, 79.8MB/s]
#
#
# model-00003-of-00003.safetensors:  33% 1.13G/3.41G [00:30<00:25, 87.9MB/s]
#
# model-00002-of-00003.safetensors:  25% 1.24G/4.99G [00:30<00:44, 84.6MB/s]
# model-00001-of-00003.safetensors:  25% 1.23G/4.99G [00:30<00:41, 89.8MB/s]
#
#
# model-00003-of-00003.safetensors:  34% 1.14G/3.41G [00:30<00:26, 86.1MB/s]
#
# model-00002-of-00003.safetensors:  25% 1.25G/4.99G [00:30<00:43, 86.0MB/s]
# model-00001-of-00003.safetensors:  25% 1.24G/4.99G [00:30<00:41, 90.0MB/s]
#
#
# model-00003-of-00003.safetensors:  34% 1.15G/3.41G [00:30<00:26, 86.7MB/s]
#
# model-00002-of-00003.safetensors:  25% 1.26G/4.99G [00:30<00:42, 88.7MB/s]
# model-00001-of-00003.safetensors:  25% 1.26G/4.99G [00:30<00:38, 97.5MB/s]
#
#
# model-00003-of-00003.safetensors:  34% 1.17G/3.41G [00:30<00:23, 94.3MB/s]
#
# model-00002-of-00003.safetensors:  26% 1.28G/4.99G [00:31<00:40, 90.8MB/s]
# model-00001-of-00003.safetensors:  25% 1.27G/4.99G [00:31<00:37, 98.5MB/s]
#
#
# model-00003-of-00003.safetensors:  35% 1.18G/3.41G [00:30<00:26, 85.4MB/s]
# model-00001-of-00003.safetensors:  26% 1.28G/4.99G [00:31<00:41, 89.4MB/s]
#
# model-00002-of-00003.safetensors:  26% 1.29G/4.99G [00:31<00:46, 79.8MB/s]
#
#
# model-00003-of-00003.safetensors:  35% 1.20G/3.41G [00:30<00:27, 79.8MB/s]
# model-00001-of-00003.safetensors:  26% 1.29G/4.99G [00:31<00:43, 85.6MB/s]
#
# model-00002-of-00003.safetensors:  26% 1.30G/4.99G [00:31<00:47, 78.4MB/s]
#
#
# model-00003-of-00003.safetensors:  35% 1.21G/3.41G [00:30<00:27, 79.5MB/s]
# model-00001-of-00003.safetensors:  26% 1.30G/4.99G [00:31<00:43, 84.8MB/s]
#
# model-00002-of-00003.safetensors:  26% 1.31G/4.99G [00:31<00:49, 74.9MB/s]
#
#
# model-00003-of-00003.safetensors:  36% 1.22G/3.41G [00:31<00:26, 82.7MB/s]
#
# model-00002-of-00003.safetensors:  26% 1.32G/4.99G [00:31<00:46, 79.6MB/s]
#
#
# model-00003-of-00003.safetensors:  36% 1.23G/3.41G [00:31<00:25, 85.4MB/s]
# model-00001-of-00003.safetensors:  26% 1.32G/4.99G [00:31<00:39, 93.7MB/s]
#
#
# model-00003-of-00003.safetensors:  36% 1.24G/3.41G [00:31<00:25, 86.0MB/s]
# model-00001-of-00003.safetensors:  27% 1.34G/4.99G [00:31<00:33, 109MB/s]
#
# model-00002-of-00003.safetensors:  27% 1.34G/4.99G [00:31<00:39, 92.9MB/s]
#
# model-00002-of-00003.safetensors:  27% 1.35G/4.99G [00:31<00:43, 83.8MB/s]
#
#
# model-00003-of-00003.safetensors:  37% 1.26G/3.41G [00:31<00:25, 84.1MB/s]
# model-00001-of-00003.safetensors:  27% 1.36G/4.99G [00:32<00:39, 90.7MB/s]
#
#
# model-00003-of-00003.safetensors:  37% 1.27G/3.41G [00:31<00:24, 87.9MB/s]
#
# model-00002-of-00003.safetensors:  27% 1.36G/4.99G [00:32<00:46, 78.7MB/s]
#
# model-00002-of-00003.safetensors:  28% 1.37G/4.99G [00:32<00:42, 84.1MB/s]
#
#
# model-00003-of-00003.safetensors:  38% 1.28G/3.41G [00:31<00:23, 89.0MB/s]
# model-00001-of-00003.safetensors:  28% 1.38G/4.99G [00:32<00:36, 99.5MB/s]
#
# model-00002-of-00003.safetensors:  28% 1.38G/4.99G [00:32<00:41, 87.0MB/s]
#
#
# model-00003-of-00003.safetensors:  38% 1.29G/3.41G [00:31<00:25, 84.4MB/s]
# model-00001-of-00003.safetensors:  28% 1.39G/4.99G [00:32<00:41, 87.4MB/s]
#
#
# model-00003-of-00003.safetensors:  38% 1.30G/3.41G [00:32<00:24, 85.6MB/s]
#
# model-00002-of-00003.safetensors:  28% 1.39G/4.99G [00:32<00:46, 77.2MB/s]
# model-00001-of-00003.safetensors:  28% 1.42G/4.99G [00:32<00:35, 101MB/s]
#
#
# model-00003-of-00003.safetensors:  39% 1.32G/3.41G [00:32<00:24, 83.5MB/s]
#
# model-00002-of-00003.safetensors:  28% 1.42G/4.99G [00:32<00:44, 80.6MB/s]
# model-00001-of-00003.safetensors:  29% 1.44G/4.99G [00:32<00:35, 101MB/s]
#
# model-00002-of-00003.safetensors:  29% 1.43G/4.99G [00:32<00:44, 80.4MB/s]
#
#
# model-00003-of-00003.safetensors:  39% 1.33G/3.41G [00:32<00:27, 74.2MB/s]
# model-00001-of-00003.safetensors:  29% 1.45G/4.99G [00:33<00:42, 83.3MB/s]
#
#
# model-00003-of-00003.safetensors:  39% 1.34G/3.41G [00:32<00:27, 76.3MB/s]
#
# model-00002-of-00003.safetensors:  29% 1.44G/4.99G [00:33<00:51, 69.6MB/s]
#
# model-00002-of-00003.safetensors:  29% 1.46G/4.99G [00:33<00:39, 90.1MB/s]
#
# model-00002-of-00003.safetensors:  30% 1.48G/4.99G [00:33<00:32, 107MB/s]
#
# model-00002-of-00003.safetensors:  30% 1.50G/4.99G [00:33<00:29, 119MB/s]
#
# model-00002-of-00003.safetensors:  30% 1.52G/4.99G [00:33<00:26, 129MB/s]
#
# model-00002-of-00003.safetensors:  31% 1.54G/4.99G [00:33<00:26, 129MB/s]
#
# model-00002-of-00003.safetensors:  31% 1.56G/4.99G [00:34<00:31, 109MB/s]
#
# model-00002-of-00003.safetensors:  32% 1.58G/4.99G [00:34<00:34, 98.8MB/s]
# model-00001-of-00003.safetensors:  29% 1.46G/4.99G [00:34<02:09, 27.3MB/s]
#
#
# model-00003-of-00003.safetensors:  40% 1.35G/3.41G [00:34<01:31, 22.6MB/s]
# model-00001-of-00003.safetensors:  29% 1.47G/4.99G [00:34<01:46, 32.9MB/s]
#
# model-00002-of-00003.safetensors:  32% 1.60G/4.99G [00:34<00:36, 92.8MB/s]
#
# model-00002-of-00003.safetensors:  32% 1.61G/4.99G [00:34<00:37, 90.6MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.63G/4.99G [00:34<00:37, 88.5MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.64G/4.99G [00:34<00:38, 86.6MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.65G/4.99G [00:35<00:39, 84.6MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.66G/4.99G [00:35<00:39, 84.7MB/s]
#
# model-00002-of-00003.safetensors:  33% 1.67G/4.99G [00:35<00:41, 79.4MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.68G/4.99G [00:35<00:41, 79.8MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.69G/4.99G [00:35<00:41, 79.8MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.70G/4.99G [00:35<00:40, 80.5MB/s]
#
#
# model-00003-of-00003.safetensors:  40% 1.36G/3.41G [00:35<02:18, 14.8MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.71G/4.99G [00:35<00:40, 80.7MB/s]
# model-00001-of-00003.safetensors:  30% 1.48G/4.99G [00:36<03:32, 16.5MB/s]
#
# model-00002-of-00003.safetensors:  34% 1.72G/4.99G [00:36<00:40, 81.1MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.73G/4.99G [00:36<00:40, 80.9MB/s]
# model-00001-of-00003.safetensors:  30% 1.50G/4.99G [00:36<02:12, 26.3MB/s]
#
#
# model-00003-of-00003.safetensors:  40% 1.37G/3.41G [00:35<02:04, 16.4MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.74G/4.99G [00:36<00:39, 81.6MB/s]
# model-00001-of-00003.safetensors:  30% 1.52G/4.99G [00:36<01:34, 36.8MB/s]
#
#
# model-00003-of-00003.safetensors:  41% 1.38G/3.41G [00:35<01:36, 21.1MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.75G/4.99G [00:36<00:41, 78.6MB/s]
#
#
# model-00003-of-00003.safetensors:  41% 1.39G/3.41G [00:36<01:14, 27.0MB/s]
# model-00001-of-00003.safetensors:  31% 1.54G/4.99G [00:36<01:11, 47.9MB/s]
#
# model-00002-of-00003.safetensors:  35% 1.76G/4.99G [00:36<00:39, 80.6MB/s]
# model-00001-of-00003.safetensors:  31% 1.56G/4.99G [00:36<00:54, 62.5MB/s]
#
# model-00002-of-00003.safetensors:  36% 1.77G/4.99G [00:36<00:39, 80.7MB/s]
#
#
# model-00003-of-00003.safetensors:  42% 1.42G/3.41G [00:36<00:48, 41.3MB/s]
# model-00001-of-00003.safetensors:  32% 1.58G/4.99G [00:36<00:42, 80.5MB/s]
#
# model-00002-of-00003.safetensors:  36% 1.78G/4.99G [00:36<00:39, 80.5MB/s]
#
#
# model-00003-of-00003.safetensors:  42% 1.44G/3.41G [00:36<00:35, 55.9MB/s]
# model-00001-of-00003.safetensors:  32% 1.60G/4.99G [00:36<00:34, 99.2MB/s]
#
# model-00002-of-00003.safetensors:  36% 1.79G/4.99G [00:36<00:39, 80.9MB/s]
#
#
# model-00003-of-00003.safetensors:  43% 1.46G/3.41G [00:36<00:27, 70.0MB/s]
#
# model-00002-of-00003.safetensors:  36% 1.80G/4.99G [00:37<00:39, 81.2MB/s]
# model-00001-of-00003.safetensors:  33% 1.63G/4.99G [00:37<00:38, 88.4MB/s]
#
#
# model-00003-of-00003.safetensors:  43% 1.48G/3.41G [00:36<00:22, 84.1MB/s]
#
# model-00002-of-00003.safetensors:  36% 1.81G/4.99G [00:37<00:39, 81.1MB/s]
#
# model-00002-of-00003.safetensors:  37% 1.82G/4.99G [00:40<05:37, 9.36MB/s]
# model-00001-of-00003.safetensors:  33% 1.65G/4.99G [00:42<04:51, 11.4MB/s]
# model-00001-of-00003.safetensors:  34% 1.68G/4.99G [00:42<02:59, 18.4MB/s]
#
# model-00002-of-00003.safetensors:  37% 1.84G/4.99G [00:42<07:14, 7.26MB/s]
# model-00001-of-00003.safetensors:  34% 1.70G/4.99G [00:42<02:17, 24.0MB/s]
#
#
# model-00003-of-00003.safetensors:  44% 1.50G/3.41G [00:42<03:05, 10.3MB/s]
#
# model-00002-of-00003.safetensors:  37% 1.85G/4.99G [00:42<05:12, 10.0MB/s]
#
#
# model-00003-of-00003.safetensors:  44% 1.51G/3.41G [00:42<02:35, 12.2MB/s]
#
# model-00002-of-00003.safetensors:  37% 1.86G/4.99G [00:43<03:54, 13.3MB/s]
# model-00001-of-00003.safetensors:  34% 1.72G/4.99G [00:43<01:47, 30.4MB/s]
#
#
# model-00003-of-00003.safetensors:  45% 1.52G/3.41G [00:42<02:08, 14.7MB/s]
#
# model-00002-of-00003.safetensors:  37% 1.87G/4.99G [00:43<02:57, 17.6MB/s]
#
#
# model-00003-of-00003.safetensors:  45% 1.53G/3.41G [00:42<01:42, 18.3MB/s]
#
# model-00002-of-00003.safetensors:  38% 1.89G/4.99G [00:43<01:47, 28.8MB/s]
#
#
# model-00003-of-00003.safetensors:  45% 1.54G/3.41G [00:43<01:21, 22.8MB/s]
# model-00001-of-00003.safetensors:  35% 1.74G/4.99G [00:43<01:32, 35.2MB/s]
#
# model-00002-of-00003.safetensors:  38% 1.90G/4.99G [00:43<01:30, 34.2MB/s]
# model-00001-of-00003.safetensors:  35% 1.76G/4.99G [00:43<01:10, 45.8MB/s]
#
#
# model-00003-of-00003.safetensors:  46% 1.56G/3.41G [00:43<00:53, 34.4MB/s]
# model-00001-of-00003.safetensors:  36% 1.78G/4.99G [00:43<00:56, 57.1MB/s]
#
# model-00002-of-00003.safetensors:  38% 1.91G/4.99G [00:43<01:20, 38.4MB/s]
#
#
# model-00003-of-00003.safetensors:  46% 1.58G/3.41G [00:43<00:38, 46.9MB/s]
#
# model-00002-of-00003.safetensors:  38% 1.92G/4.99G [00:43<01:11, 42.8MB/s]
# model-00001-of-00003.safetensors:  36% 1.80G/4.99G [00:43<00:48, 65.0MB/s]
#
#
# model-00003-of-00003.safetensors:  47% 1.59G/3.41G [00:43<00:35, 50.4MB/s]
#
#
# model-00003-of-00003.safetensors:  47% 1.60G/3.41G [00:43<00:31, 57.0MB/s]
#
#
# model-00003-of-00003.safetensors:  47% 1.61G/3.41G [00:43<00:29, 61.7MB/s]
#
# model-00002-of-00003.safetensors:  39% 1.94G/4.99G [00:44<00:57, 52.9MB/s]
# model-00001-of-00003.safetensors:  37% 1.82G/4.99G [00:44<00:47, 66.4MB/s]
#
# model-00002-of-00003.safetensors:  39% 1.95G/4.99G [00:44<00:51, 59.5MB/s]
#
#
# model-00003-of-00003.safetensors:  48% 1.64G/3.41G [00:44<00:24, 73.1MB/s]
#
# model-00002-of-00003.safetensors:  39% 1.96G/4.99G [00:44<00:47, 63.5MB/s]
# model-00001-of-00003.safetensors:  37% 1.84G/4.99G [00:44<00:49, 64.3MB/s]
#
#
# model-00003-of-00003.safetensors:  49% 1.66G/3.41G [00:44<00:20, 85.0MB/s]
#
# model-00002-of-00003.safetensors:  40% 1.98G/4.99G [00:44<00:37, 79.8MB/s]
# model-00001-of-00003.safetensors:  37% 1.85G/4.99G [00:44<00:51, 60.9MB/s]
#
#
# model-00003-of-00003.safetensors:  49% 1.67G/3.41G [00:44<00:21, 80.1MB/s]
#
# model-00002-of-00003.safetensors:  40% 1.99G/4.99G [00:44<00:38, 76.9MB/s]
# model-00001-of-00003.safetensors:  37% 1.86G/4.99G [00:44<00:50, 62.0MB/s]
#
#
# model-00003-of-00003.safetensors:  50% 1.69G/3.41G [00:44<00:18, 91.0MB/s]
#
# model-00002-of-00003.safetensors:  40% 2.01G/4.99G [00:44<00:33, 90.0MB/s]
# model-00001-of-00003.safetensors:  38% 1.88G/4.99G [00:45<00:41, 74.7MB/s]
#
#
# model-00003-of-00003.safetensors:  50% 1.70G/3.41G [00:44<00:21, 80.6MB/s]
#
# model-00002-of-00003.safetensors:  41% 2.02G/4.99G [00:45<00:37, 78.2MB/s]
# model-00001-of-00003.safetensors:  38% 1.89G/4.99G [00:45<00:43, 71.2MB/s]
#
# model-00002-of-00003.safetensors:  41% 2.03G/4.99G [00:45<00:36, 80.8MB/s]
#
#
# model-00003-of-00003.safetensors:  50% 1.72G/3.41G [00:44<00:18, 91.5MB/s]
# model-00001-of-00003.safetensors:  38% 1.90G/4.99G [00:45<00:41, 74.4MB/s]
#
# model-00002-of-00003.safetensors:  41% 2.06G/4.99G [00:45<00:30, 95.2MB/s]
# model-00001-of-00003.safetensors:  38% 1.91G/4.99G [00:45<00:41, 73.5MB/s]
#
#
# model-00003-of-00003.safetensors:  51% 1.74G/3.41G [00:45<00:17, 94.5MB/s]
# model-00001-of-00003.safetensors:  38% 1.92G/4.99G [00:45<00:41, 73.1MB/s]
#
# model-00002-of-00003.safetensors:  41% 2.07G/4.99G [00:45<00:37, 77.3MB/s]
#
#
# model-00003-of-00003.safetensors:  51% 1.75G/3.41G [00:45<00:18, 89.4MB/s]
# model-00001-of-00003.safetensors:  39% 1.93G/4.99G [00:45<00:42, 72.8MB/s]
#
# model-00002-of-00003.safetensors:  42% 2.08G/4.99G [00:45<00:35, 81.0MB/s]
#
#
# model-00003-of-00003.safetensors:  52% 1.77G/3.41G [00:45<00:16, 97.0MB/s]
# model-00001-of-00003.safetensors:  39% 1.94G/4.99G [00:45<00:42, 71.6MB/s]
#
# model-00002-of-00003.safetensors:  42% 2.10G/4.99G [00:45<00:30, 93.8MB/s]
# model-00001-of-00003.safetensors:  39% 1.95G/4.99G [00:46<00:49, 61.3MB/s]
#
# model-00002-of-00003.safetensors:  42% 2.11G/4.99G [00:46<00:36, 78.4MB/s]
#
#
# model-00003-of-00003.safetensors:  53% 1.79G/3.41G [00:45<00:19, 84.8MB/s]
# model-00001-of-00003.safetensors:  39% 1.96G/4.99G [00:46<00:43, 69.4MB/s]
#
# model-00002-of-00003.safetensors:  43% 2.13G/4.99G [00:46<00:36, 78.0MB/s]
#
#
# model-00003-of-00003.safetensors:  53% 1.81G/3.41G [00:46<00:20, 79.1MB/s]
# model-00001-of-00003.safetensors:  40% 1.98G/4.99G [00:46<00:41, 72.4MB/s]
#
# model-00002-of-00003.safetensors:  43% 2.14G/4.99G [00:46<00:35, 79.3MB/s]
#
#
# model-00003-of-00003.safetensors:  54% 1.84G/3.41G [00:46<00:17, 89.9MB/s]
# model-00001-of-00003.safetensors:  40% 1.99G/4.99G [00:46<00:38, 76.8MB/s]
#
# model-00002-of-00003.safetensors:  43% 2.16G/4.99G [00:46<00:32, 87.6MB/s]
#
#
# model-00003-of-00003.safetensors:  54% 1.85G/3.41G [00:46<00:17, 87.0MB/s]
# model-00001-of-00003.safetensors:  40% 2.00G/4.99G [00:46<00:38, 76.8MB/s]
#
# model-00002-of-00003.safetensors:  44% 2.17G/4.99G [00:46<00:32, 87.3MB/s]
# model-00001-of-00003.safetensors:  40% 2.01G/4.99G [00:46<00:39, 75.2MB/s]
#
#
# model-00003-of-00003.safetensors:  55% 1.87G/3.41G [00:46<00:16, 94.0MB/s]
#
# model-00002-of-00003.safetensors:  44% 2.19G/4.99G [00:47<00:28, 97.0MB/s]
# model-00001-of-00003.safetensors:  41% 2.02G/4.99G [00:47<00:39, 74.3MB/s]
#
#
# model-00003-of-00003.safetensors:  55% 1.88G/3.41G [00:46<00:17, 87.6MB/s]
#
# model-00002-of-00003.safetensors:  44% 2.20G/4.99G [00:47<00:28, 96.6MB/s]
# model-00001-of-00003.safetensors:  41% 2.03G/4.99G [00:47<00:39, 74.8MB/s]
#
#
# model-00003-of-00003.safetensors:  56% 1.90G/3.41G [00:46<00:15, 96.3MB/s]
# model-00001-of-00003.safetensors:  41% 2.04G/4.99G [00:47<00:40, 73.2MB/s]
#
# model-00002-of-00003.safetensors:  45% 2.22G/4.99G [00:47<00:28, 98.5MB/s]
#
#
# model-00003-of-00003.safetensors:  56% 1.91G/3.41G [00:46<00:16, 92.4MB/s]
# model-00001-of-00003.safetensors:  41% 2.06G/4.99G [00:47<00:39, 73.6MB/s]
#
# model-00002-of-00003.safetensors:  45% 2.24G/4.99G [00:47<00:29, 94.4MB/s]
# model-00001-of-00003.safetensors:  41% 2.07G/4.99G [00:47<00:39, 73.8MB/s]
#
#
# model-00003-of-00003.safetensors:  57% 1.93G/3.41G [00:47<00:16, 91.7MB/s]
#
# model-00002-of-00003.safetensors:  45% 2.25G/4.99G [00:47<00:28, 96.0MB/s]
#
#
# model-00003-of-00003.safetensors:  57% 1.94G/3.41G [00:47<00:16, 89.5MB/s]
# model-00001-of-00003.safetensors:  42% 2.08G/4.99G [00:47<00:40, 72.5MB/s]
#
# model-00002-of-00003.safetensors:  45% 2.26G/4.99G [00:47<00:28, 96.1MB/s]
#
#
# model-00003-of-00003.safetensors:  57% 1.95G/3.41G [00:47<00:16, 87.7MB/s]
#
# model-00002-of-00003.safetensors:  46% 2.28G/4.99G [00:47<00:28, 93.5MB/s]
# model-00001-of-00003.safetensors:  42% 2.09G/4.99G [00:47<00:42, 67.5MB/s]
#
#
# model-00003-of-00003.safetensors:  58% 1.96G/3.41G [00:47<00:17, 84.1MB/s]
#
# model-00002-of-00003.safetensors:  46% 2.30G/4.99G [00:48<00:29, 91.8MB/s]
#
#
# model-00003-of-00003.safetensors:  58% 1.97G/3.41G [00:47<00:17, 82.5MB/s]
# model-00001-of-00003.safetensors:  42% 2.11G/4.99G [00:48<00:38, 75.1MB/s]
#
# model-00002-of-00003.safetensors:  46% 2.31G/4.99G [00:48<00:35, 74.9MB/s]
#
#
# model-00003-of-00003.safetensors:  58% 1.98G/3.41G [00:47<00:21, 67.2MB/s]
# model-00001-of-00003.safetensors:  42% 2.12G/4.99G [00:48<00:45, 63.5MB/s]
# model-00001-of-00003.safetensors:  43% 2.13G/4.99G [00:52<05:44, 8.29MB/s]
#
# model-00002-of-00003.safetensors:  46% 2.32G/4.99G [00:52<05:02, 8.81MB/s]
#
#
# model-00003-of-00003.safetensors:  58% 1.99G/3.41G [00:52<03:02, 7.76MB/s]
# model-00001-of-00003.safetensors:  43% 2.15G/4.99G [00:52<03:23, 13.9MB/s]
#
#
# model-00003-of-00003.safetensors:  59% 2.01G/3.41G [00:52<01:44, 13.4MB/s]
#
# model-00002-of-00003.safetensors:  47% 2.34G/4.99G [00:52<03:05, 14.3MB/s]
# model-00001-of-00003.safetensors:  44% 2.17G/4.99G [00:53<02:12, 21.2MB/s]
#
# model-00002-of-00003.safetensors:  47% 2.35G/4.99G [00:53<02:29, 17.7MB/s]
#
#
# model-00003-of-00003.safetensors:  59% 2.02G/3.41G [00:52<01:22, 16.8MB/s]
# model-00001-of-00003.safetensors:  44% 2.18G/4.99G [00:53<01:50, 25.4MB/s]
#
# model-00002-of-00003.safetensors:  47% 2.36G/4.99G [00:53<01:58, 22.1MB/s]
#
#
# model-00003-of-00003.safetensors:  60% 2.03G/3.41G [00:52<01:04, 21.3MB/s]
# model-00001-of-00003.safetensors:  44% 2.19G/4.99G [00:53<01:32, 30.2MB/s]
#
# model-00002-of-00003.safetensors:  48% 2.37G/4.99G [00:53<01:37, 26.8MB/s]
#
#
# model-00003-of-00003.safetensors:  60% 2.06G/3.41G [00:52<00:42, 32.1MB/s]
#
# model-00002-of-00003.safetensors:  48% 2.38G/4.99G [00:53<01:18, 33.4MB/s]
# model-00001-of-00003.safetensors:  44% 2.20G/4.99G [00:53<01:19, 35.0MB/s]
#
#
# model-00003-of-00003.safetensors:  61% 2.07G/3.41G [00:53<00:36, 36.7MB/s]
#
# model-00002-of-00003.safetensors:  48% 2.39G/4.99G [00:53<01:06, 38.8MB/s]
# model-00001-of-00003.safetensors:  44% 2.21G/4.99G [00:53<01:08, 40.3MB/s]
#
#
# model-00003-of-00003.safetensors:  61% 2.08G/3.41G [00:53<00:30, 43.0MB/s]
#
# model-00002-of-00003.safetensors:  48% 2.40G/4.99G [00:53<00:55, 46.3MB/s]
#
#
# model-00003-of-00003.safetensors:  61% 2.09G/3.41G [00:53<00:26, 49.0MB/s]
#
# model-00002-of-00003.safetensors:  48% 2.41G/4.99G [00:53<00:48, 52.7MB/s]
# model-00001-of-00003.safetensors:  45% 2.23G/4.99G [00:53<00:52, 52.3MB/s]
#
#
# model-00003-of-00003.safetensors:  62% 2.11G/3.41G [00:53<00:21, 61.4MB/s]
# model-00001-of-00003.safetensors:  45% 2.25G/4.99G [00:54<00:44, 62.1MB/s]
#
# model-00002-of-00003.safetensors:  49% 2.43G/4.99G [00:54<00:40, 63.0MB/s]
#
#
# model-00003-of-00003.safetensors:  62% 2.12G/3.41G [00:53<00:20, 62.7MB/s]
# model-00001-of-00003.safetensors:  45% 2.26G/4.99G [00:54<00:41, 65.4MB/s]
#
# model-00002-of-00003.safetensors:  49% 2.44G/4.99G [00:54<00:38, 66.7MB/s]
#
#
# model-00003-of-00003.safetensors:  63% 2.14G/3.41G [00:53<00:15, 79.8MB/s]
#
# model-00002-of-00003.safetensors:  49% 2.45G/4.99G [00:54<00:34, 73.2MB/s]
# model-00001-of-00003.safetensors:  46% 2.28G/4.99G [00:54<00:38, 71.1MB/s]
# model-00001-of-00003.safetensors:  46% 2.29G/4.99G [00:54<00:34, 77.3MB/s]
#
# model-00002-of-00003.safetensors:  49% 2.46G/4.99G [00:54<00:31, 79.0MB/s]
#
#
# model-00003-of-00003.safetensors:  63% 2.16G/3.41G [00:54<00:15, 81.9MB/s]
#
# model-00002-of-00003.safetensors:  50% 2.47G/4.99G [00:54<00:33, 74.4MB/s]
# model-00001-of-00003.safetensors:  46% 2.30G/4.99G [00:54<00:37, 72.4MB/s]
#
#
# model-00003-of-00003.safetensors:  64% 2.17G/3.41G [00:54<00:16, 76.3MB/s]
#
# model-00002-of-00003.safetensors:  50% 2.49G/4.99G [00:54<00:34, 73.5MB/s]
# model-00001-of-00003.safetensors:  46% 2.31G/4.99G [00:54<00:37, 71.3MB/s]
#
#
# model-00003-of-00003.safetensors:  64% 2.18G/3.41G [00:54<00:15, 78.0MB/s]
# model-00001-of-00003.safetensors:  46% 2.32G/4.99G [00:54<00:36, 73.2MB/s]
#
# model-00002-of-00003.safetensors:  50% 2.50G/4.99G [00:54<00:35, 70.9MB/s]
#
#
# model-00003-of-00003.safetensors:  64% 2.19G/3.41G [00:54<00:16, 75.6MB/s]
# model-00001-of-00003.safetensors:  47% 2.33G/4.99G [00:55<00:35, 74.2MB/s]
#
# model-00002-of-00003.safetensors:  50% 2.51G/4.99G [00:55<00:35, 69.6MB/s]
#
#
# model-00003-of-00003.safetensors:  65% 2.20G/3.41G [00:54<00:15, 77.6MB/s]
# model-00001-of-00003.safetensors:  47% 2.34G/4.99G [00:55<00:34, 77.3MB/s]
#
# model-00002-of-00003.safetensors:  50% 2.52G/4.99G [00:55<00:32, 74.8MB/s]
#
#
# model-00003-of-00003.safetensors:  65% 2.21G/3.41G [00:54<00:14, 80.0MB/s]
#
# model-00002-of-00003.safetensors:  51% 2.53G/4.99G [00:55<00:31, 77.8MB/s]
# model-00001-of-00003.safetensors:  47% 2.35G/4.99G [00:55<00:36, 72.6MB/s]
#
#
# model-00003-of-00003.safetensors:  65% 2.22G/3.41G [00:54<00:14, 80.2MB/s]
# model-00001-of-00003.safetensors:  47% 2.36G/4.99G [00:55<00:33, 78.6MB/s]
#
# model-00002-of-00003.safetensors:  51% 2.54G/4.99G [00:55<00:30, 80.7MB/s]
#
#
# model-00003-of-00003.safetensors:  66% 2.23G/3.41G [00:55<00:14, 81.8MB/s]
#
# model-00002-of-00003.safetensors:  51% 2.55G/4.99G [00:55<00:29, 82.9MB/s]
# model-00001-of-00003.safetensors:  48% 2.37G/4.99G [00:55<00:37, 69.7MB/s]
#
# model-00002-of-00003.safetensors:  51% 2.56G/4.99G [00:55<00:28, 84.2MB/s]
#
#
# model-00003-of-00003.safetensors:  66% 2.25G/3.41G [00:55<00:12, 91.8MB/s]
# model-00001-of-00003.safetensors:  48% 2.38G/4.99G [00:55<00:38, 67.1MB/s]
#
#
# model-00003-of-00003.safetensors:  66% 2.26G/3.41G [00:55<00:13, 82.9MB/s]
#
# model-00002-of-00003.safetensors:  52% 2.58G/4.99G [00:55<00:27, 88.8MB/s]
# model-00001-of-00003.safetensors:  48% 2.39G/4.99G [00:55<00:37, 69.1MB/s]
# model-00001-of-00003.safetensors:  48% 2.40G/4.99G [00:56<00:37, 68.5MB/s]
#
#
# model-00003-of-00003.safetensors:  67% 2.29G/3.41G [00:55<00:12, 88.4MB/s]
#
# model-00002-of-00003.safetensors:  52% 2.60G/4.99G [00:56<00:25, 92.8MB/s]
# model-00001-of-00003.safetensors:  48% 2.41G/4.99G [00:56<00:36, 70.7MB/s]
#
# model-00002-of-00003.safetensors:  52% 2.61G/4.99G [00:56<00:26, 88.9MB/s]
#
#
# model-00003-of-00003.safetensors:  67% 2.30G/3.41G [00:55<00:13, 84.2MB/s]
# model-00001-of-00003.safetensors:  49% 2.42G/4.99G [00:56<00:34, 74.4MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.62G/4.99G [00:56<00:26, 87.9MB/s]
#
#
# model-00003-of-00003.safetensors:  68% 2.32G/3.41G [00:56<00:12, 89.4MB/s]
# model-00001-of-00003.safetensors:  49% 2.43G/4.99G [00:56<00:32, 79.2MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.63G/4.99G [00:56<00:25, 91.6MB/s]
#
#
# model-00003-of-00003.safetensors:  68% 2.33G/3.41G [00:56<00:11, 90.1MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.64G/4.99G [00:56<00:26, 88.7MB/s]
# model-00001-of-00003.safetensors:  49% 2.44G/4.99G [00:56<00:31, 81.9MB/s]
# model-00001-of-00003.safetensors:  49% 2.45G/4.99G [00:56<00:30, 82.1MB/s]
#
#
# model-00003-of-00003.safetensors:  69% 2.34G/3.41G [00:56<00:12, 85.2MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.65G/4.99G [00:56<00:28, 81.6MB/s]
# model-00001-of-00003.safetensors:  49% 2.46G/4.99G [00:56<00:30, 82.9MB/s]
#
#
# model-00003-of-00003.safetensors:  69% 2.35G/3.41G [00:56<00:12, 85.8MB/s]
#
# model-00002-of-00003.safetensors:  53% 2.66G/4.99G [00:56<00:29, 79.8MB/s]
# model-00001-of-00003.safetensors:  50% 2.47G/4.99G [00:56<00:31, 80.6MB/s]
#
#
# model-00003-of-00003.safetensors:  69% 2.36G/3.41G [00:56<00:12, 82.9MB/s]
#
# model-00002-of-00003.safetensors:  54% 2.67G/4.99G [00:56<00:27, 85.1MB/s]
#
#
# model-00003-of-00003.safetensors:  70% 2.37G/3.41G [00:56<00:12, 85.7MB/s]
#
# model-00002-of-00003.safetensors:  54% 2.68G/4.99G [00:57<00:27, 83.1MB/s]
#
#
# model-00003-of-00003.safetensors:  70% 2.38G/3.41G [00:56<00:11, 86.5MB/s]
#
# model-00002-of-00003.safetensors:  54% 2.69G/4.99G [00:57<00:25, 88.4MB/s]
# model-00001-of-00003.safetensors:  50% 2.49G/4.99G [00:57<00:45, 54.9MB/s]
#
# model-00002-of-00003.safetensors:  54% 2.71G/4.99G [00:57<00:24, 92.2MB/s]
#
#
# model-00003-of-00003.safetensors:  70% 2.40G/3.41G [00:56<00:10, 99.6MB/s]
#
# model-00002-of-00003.safetensors:  54% 2.72G/4.99G [00:57<00:24, 92.9MB/s]
# model-00001-of-00003.safetensors:  50% 2.51G/4.99G [00:57<00:34, 71.1MB/s]
#
#
# model-00003-of-00003.safetensors:  71% 2.42G/3.41G [00:57<00:09, 107MB/s]
# model-00001-of-00003.safetensors:  50% 2.52G/4.99G [00:57<00:33, 74.4MB/s]
#
# model-00002-of-00003.safetensors:  55% 2.74G/4.99G [00:57<00:23, 97.1MB/s]
# model-00001-of-00003.safetensors:  51% 2.53G/4.99G [00:57<00:30, 80.5MB/s]
#
#
# model-00003-of-00003.safetensors:  72% 2.44G/3.41G [00:57<00:09, 106MB/s]
#
# model-00002-of-00003.safetensors:  55% 2.75G/4.99G [00:57<00:23, 94.5MB/s]
# model-00001-of-00003.safetensors:  51% 2.55G/4.99G [00:57<00:26, 91.1MB/s]
# model-00001-of-00003.safetensors:  52% 2.57G/4.99G [00:58<00:22, 109MB/s]
#
#
# model-00003-of-00003.safetensors:  72% 2.46G/3.41G [00:57<00:11, 80.2MB/s]
#
# model-00002-of-00003.safetensors:  56% 2.77G/4.99G [00:58<00:31, 69.6MB/s]
# model-00001-of-00003.safetensors:  52% 2.59G/4.99G [00:58<00:20, 116MB/s]
#
#
# model-00003-of-00003.safetensors:  73% 2.49G/3.41G [00:57<00:10, 89.3MB/s]
#
# model-00002-of-00003.safetensors:  56% 2.79G/4.99G [00:58<00:28, 77.5MB/s]
# model-00001-of-00003.safetensors:  52% 2.61G/4.99G [00:58<00:22, 106MB/s]
#
#
# model-00003-of-00003.safetensors:  74% 2.51G/3.41G [00:58<00:09, 97.8MB/s]
#
# model-00002-of-00003.safetensors:  56% 2.81G/4.99G [00:58<00:24, 87.5MB/s]
# model-00001-of-00003.safetensors:  53% 2.63G/4.99G [00:58<00:25, 94.2MB/s]
#
# model-00002-of-00003.safetensors:  57% 2.83G/4.99G [00:58<00:21, 100MB/s]
#
#
# model-00003-of-00003.safetensors:  74% 2.53G/3.41G [00:58<00:09, 92.8MB/s]
# model-00001-of-00003.safetensors:  53% 2.64G/4.99G [00:58<00:26, 88.8MB/s]
#
#
# model-00003-of-00003.safetensors:  74% 2.54G/3.41G [00:58<00:09, 89.4MB/s]
# model-00001-of-00003.safetensors:  53% 2.65G/4.99G [00:58<00:27, 86.0MB/s]
#
#
# model-00003-of-00003.safetensors:  75% 2.55G/3.41G [00:58<00:09, 87.1MB/s]
#
# model-00002-of-00003.safetensors:  57% 2.85G/4.99G [00:59<00:24, 88.6MB/s]
# model-00001-of-00003.safetensors:  53% 2.66G/4.99G [00:59<00:27, 84.6MB/s]
#
#
# model-00003-of-00003.safetensors:  75% 2.56G/3.41G [00:58<00:09, 85.6MB/s]
#
# model-00002-of-00003.safetensors:  57% 2.86G/4.99G [00:59<00:25, 82.0MB/s]
# model-00001-of-00003.safetensors:  54% 2.67G/4.99G [00:59<00:28, 80.6MB/s]
#
#
# model-00003-of-00003.safetensors:  75% 2.57G/3.41G [00:58<00:10, 83.5MB/s]
#
# model-00002-of-00003.safetensors:  58% 2.87G/4.99G [00:59<00:26, 80.0MB/s]
#
#
# model-00003-of-00003.safetensors:  76% 2.58G/3.41G [00:58<00:10, 82.7MB/s]
# model-00001-of-00003.safetensors:  54% 2.68G/4.99G [00:59<00:29, 78.2MB/s]
#
# model-00002-of-00003.safetensors:  58% 2.88G/4.99G [00:59<00:26, 79.3MB/s]
# model-00001-of-00003.safetensors:  54% 2.69G/4.99G [00:59<00:28, 79.4MB/s]
#
#
# model-00003-of-00003.safetensors:  76% 2.59G/3.41G [00:59<00:10, 79.7MB/s]
#
# model-00002-of-00003.safetensors:  58% 2.90G/4.99G [00:59<00:22, 94.2MB/s]
#
#
# model-00003-of-00003.safetensors:  76% 2.60G/3.41G [00:59<00:09, 82.0MB/s]
# ...
#
# model-00002-of-00003.safetensors:  74% 3.69G/4.99G [01:18<00:17, 72.6MB/s]
#
#
# model-00003-of-00003.safetensors:  98% 3.36G/3.41G [01:18<00:00, 68.4MB/s]
# model-00001-of-00003.safetensors:  70% 3.47G/4.99G [01:18<00:21, 71.7MB/s]
#
# model-00002-of-00003.safetensors:  74% 3.70G/4.99G [01:18<00:17, 71.4MB/s]
#
#
# model-00003-of-00003.safetensors:  99% 3.38G/3.41G [01:18<00:00, 81.3MB/s]
# model-00001-of-00003.safetensors:  70% 3.49G/4.99G [01:18<00:17, 84.8MB/s]
#
# model-00002-of-00003.safetensors:  75% 3.72G/4.99G [01:18<00:15, 83.1MB/s]
#
#
# model-00003-of-00003.safetensors: 100% 3.40G/3.41G [01:18<00:00, 88.3MB/s]
# model-00001-of-00003.safetensors:  70% 3.51G/4.99G [01:18<00:15, 92.2MB/s]
#
# model-00002-of-00003.safetensors:  75% 3.73G/4.99G [01:18<00:16, 75.4MB/s]
# model-00003-of-00003.safetensors: 100% 3.41G/3.41G [01:18<00:00, 43.4MB/s]
#
#
# model-00002-of-00003.safetensors:  75% 3.75G/4.99G [01:19<00:13, 88.0MB/s]
# model-00001-of-00003.safetensors:  71% 3.54G/4.99G [01:19<00:13, 107MB/s]
#
# model-00002-of-00003.safetensors:  76% 3.77G/4.99G [01:19<00:13, 92.2MB/s]
# model-00001-of-00003.safetensors:  72% 3.57G/4.99G [01:19<00:13, 105MB/s]
#
# model-00002-of-00003.safetensors:  76% 3.79G/4.99G [01:19<00:13, 90.9MB/s]
# model-00001-of-00003.safetensors:  72% 3.59G/4.99G [01:19<00:13, 106MB/s]
#
# model-00002-of-00003.safetensors:  76% 3.81G/4.99G [01:19<00:11, 99.4MB/s]
#
# model-00002-of-00003.safetensors:  77% 3.83G/4.99G [01:19<00:10, 109MB/s]
# model-00001-of-00003.safetensors:  72% 3.61G/4.99G [01:19<00:14, 97.8MB/s]
#
# model-00002-of-00003.safetensors:  77% 3.85G/4.99G [01:19<00:10, 107MB/s]
# model-00001-of-00003.safetensors:  73% 3.62G/4.99G [01:19<00:16, 84.0MB/s]
#
# model-00002-of-00003.safetensors:  78% 3.87G/4.99G [01:20<00:10, 108MB/s]
# model-00001-of-00003.safetensors:  73% 3.63G/4.99G [01:20<00:17, 79.1MB/s]
# model-00001-of-00003.safetensors:  73% 3.64G/4.99G [01:20<00:17, 78.7MB/s]
#
# model-00002-of-00003.safetensors:  78% 3.89G/4.99G [01:20<00:10, 105MB/s]
# model-00001-of-00003.safetensors:  73% 3.65G/4.99G [01:20<00:17, 76.7MB/s]
#
# model-00002-of-00003.safetensors:  78% 3.91G/4.99G [01:20<00:09, 111MB/s]
# model-00001-of-00003.safetensors:  73% 3.66G/4.99G [01:20<00:19, 68.2MB/s]
#
# model-00002-of-00003.safetensors:  79% 3.93G/4.99G [01:25<01:25, 12.4MB/s]
# model-00001-of-00003.safetensors:  74% 3.67G/4.99G [01:25<03:07, 7.02MB/s]
#
# model-00002-of-00003.safetensors:  79% 3.95G/4.99G [01:25<00:59, 17.3MB/s]
#
# model-00002-of-00003.safetensors:  80% 3.97G/4.99G [01:25<00:42, 23.6MB/s]
# model-00001-of-00003.safetensors:  74% 3.69G/4.99G [01:25<01:48, 12.0MB/s]
# model-00001-of-00003.safetensors:  74% 3.71G/4.99G [01:26<01:09, 18.5MB/s]
#
# model-00002-of-00003.safetensors:  80% 4.00G/4.99G [01:26<00:31, 31.1MB/s]
# model-00001-of-00003.safetensors:  75% 3.72G/4.99G [01:26<00:56, 22.3MB/s]
#
# model-00002-of-00003.safetensors:  81% 4.02G/4.99G [01:26<00:24, 39.8MB/s]
# model-00001-of-00003.safetensors:  75% 3.74G/4.99G [01:26<00:37, 32.7MB/s]
#
# model-00002-of-00003.safetensors:  81% 4.04G/4.99G [01:26<00:18, 50.8MB/s]
# model-00001-of-00003.safetensors:  75% 3.76G/4.99G [01:26<00:27, 44.9MB/s]
#
# model-00002-of-00003.safetensors:  81% 4.06G/4.99G [01:26<00:14, 62.2MB/s]
#
# model-00002-of-00003.safetensors:  82% 4.08G/4.99G [01:26<00:12, 75.1MB/s]
# model-00001-of-00003.safetensors:  76% 3.79G/4.99G [01:26<00:24, 48.8MB/s]
#
# model-00002-of-00003.safetensors:  82% 4.10G/4.99G [01:26<00:09, 89.0MB/s]
#
# model-00002-of-00003.safetensors:  83% 4.12G/4.99G [01:26<00:08, 99.7MB/s]
# model-00001-of-00003.safetensors:  76% 3.80G/4.99G [01:27<00:25, 47.2MB/s]
#
# model-00002-of-00003.safetensors:  83% 4.14G/4.99G [01:27<00:09, 93.4MB/s]
# model-00001-of-00003.safetensors:  76% 3.81G/4.99G [01:27<00:26, 43.9MB/s]
#
# model-00002-of-00003.safetensors:  83% 4.16G/4.99G [01:27<00:09, 89.6MB/s]
# model-00001-of-00003.safetensors:  77% 3.82G/4.99G [01:27<00:26, 43.4MB/s]
#
# model-00002-of-00003.safetensors:  84% 4.18G/4.99G [01:27<00:09, 85.9MB/s]
#
# model-00002-of-00003.safetensors:  84% 4.19G/4.99G [01:27<00:09, 86.2MB/s]
# model-00001-of-00003.safetensors:  77% 3.83G/4.99G [01:27<00:28, 40.9MB/s]
#
# model-00002-of-00003.safetensors:  84% 4.20G/4.99G [01:27<00:09, 85.2MB/s]
#
# model-00002-of-00003.safetensors:  85% 4.22G/4.99G [01:28<00:09, 84.4MB/s]
# model-00001-of-00003.safetensors:  77% 3.84G/4.99G [01:28<00:27, 41.0MB/s]
#
# model-00002-of-00003.safetensors:  85% 4.23G/4.99G [01:28<00:11, 66.7MB/s]
# model-00001-of-00003.safetensors:  77% 3.85G/4.99G [01:28<00:28, 39.5MB/s]
#
# model-00002-of-00003.safetensors:  85% 4.25G/4.99G [01:28<00:09, 79.0MB/s]
# model-00001-of-00003.safetensors:  77% 3.86G/4.99G [01:28<00:28, 40.2MB/s]
#
# model-00002-of-00003.safetensors:  86% 4.27G/4.99G [01:28<00:08, 88.3MB/s]
#
# model-00002-of-00003.safetensors:  86% 4.28G/4.99G [01:28<00:08, 86.6MB/s]
# model-00001-of-00003.safetensors:  78% 3.87G/4.99G [01:28<00:27, 40.8MB/s]
#
# model-00002-of-00003.safetensors:  86% 4.29G/4.99G [01:29<00:08, 85.9MB/s]
#
# model-00002-of-00003.safetensors:  86% 4.30G/4.99G [01:29<00:08, 84.7MB/s]
# model-00001-of-00003.safetensors:  78% 3.88G/4.99G [01:29<00:28, 39.1MB/s]
#
# model-00002-of-00003.safetensors:  86% 4.31G/4.99G [01:29<00:08, 83.5MB/s]
#
# model-00002-of-00003.safetensors:  87% 4.32G/4.99G [01:29<00:07, 83.4MB/s]
# model-00001-of-00003.safetensors:  78% 3.89G/4.99G [01:29<00:27, 39.9MB/s]
#
# model-00002-of-00003.safetensors:  87% 4.33G/4.99G [01:29<00:07, 83.0MB/s]
#
# model-00002-of-00003.safetensors:  87% 4.34G/4.99G [01:29<00:07, 82.7MB/s]
# model-00001-of-00003.safetensors:  78% 3.90G/4.99G [01:29<00:26, 40.5MB/s]
#
# model-00002-of-00003.safetensors:  87% 4.35G/4.99G [01:29<00:07, 82.2MB/s]
#
# model-00002-of-00003.safetensors:  87% 4.36G/4.99G [01:29<00:07, 82.0MB/s]
# model-00001-of-00003.safetensors:  78% 3.91G/4.99G [01:30<00:27, 39.0MB/s]
#
# model-00002-of-00003.safetensors:  88% 4.37G/4.99G [01:30<00:07, 81.8MB/s]
#
# model-00002-of-00003.safetensors:  88% 4.38G/4.99G [01:30<00:07, 81.6MB/s]
# model-00001-of-00003.safetensors:  79% 3.92G/4.99G [01:30<00:26, 39.8MB/s]
#
# model-00002-of-00003.safetensors:  88% 4.39G/4.99G [01:30<00:07, 81.5MB/s]
#
# model-00002-of-00003.safetensors:  88% 4.40G/4.99G [01:30<00:07, 81.5MB/s]
# model-00001-of-00003.safetensors:  79% 3.93G/4.99G [01:30<00:26, 40.3MB/s]
#
# model-00002-of-00003.safetensors:  89% 4.41G/4.99G [01:30<00:07, 81.4MB/s]
#
# model-00002-of-00003.safetensors:  89% 4.42G/4.99G [01:30<00:06, 81.6MB/s]
# model-00001-of-00003.safetensors:  79% 3.94G/4.99G [01:30<00:26, 39.3MB/s]
#
# model-00002-of-00003.safetensors:  89% 4.44G/4.99G [01:30<00:07, 77.0MB/s]
#
# model-00002-of-00003.safetensors:  89% 4.45G/4.99G [01:30<00:06, 77.7MB/s]
# model-00001-of-00003.safetensors:  79% 3.95G/4.99G [01:31<00:27, 38.1MB/s]
#
# model-00002-of-00003.safetensors:  89% 4.46G/4.99G [01:31<00:06, 78.6MB/s]
#
# model-00002-of-00003.safetensors:  90% 4.47G/4.99G [01:31<00:07, 70.9MB/s]
# model-00001-of-00003.safetensors:  79% 3.96G/4.99G [01:31<00:24, 41.2MB/s]
#
# model-00002-of-00003.safetensors:  90% 4.49G/4.99G [01:31<00:06, 82.1MB/s]
# model-00001-of-00003.safetensors:  80% 3.97G/4.99G [01:31<00:24, 41.3MB/s]
#
# model-00002-of-00003.safetensors:  90% 4.50G/4.99G [01:31<00:05, 81.3MB/s]
#
# model-00002-of-00003.safetensors:  90% 4.51G/4.99G [01:31<00:05, 81.9MB/s]
# model-00001-of-00003.safetensors:  80% 3.98G/4.99G [01:31<00:24, 41.4MB/s]
#
# model-00002-of-00003.safetensors:  91% 4.52G/4.99G [01:31<00:05, 81.8MB/s]
#
# model-00002-of-00003.safetensors:  91% 4.53G/4.99G [01:32<00:05, 79.7MB/s]
# model-00001-of-00003.safetensors:  80% 4.00G/4.99G [01:32<00:24, 40.2MB/s]
#
# model-00002-of-00003.safetensors:  91% 4.54G/4.99G [01:32<00:05, 82.0MB/s]
#
# model-00002-of-00003.safetensors:  91% 4.55G/4.99G [01:32<00:05, 82.1MB/s]
# model-00001-of-00003.safetensors:  80% 4.01G/4.99G [01:32<00:24, 40.7MB/s]
#
# model-00002-of-00003.safetensors:  91% 4.56G/4.99G [01:32<00:05, 81.8MB/s]
# model-00001-of-00003.safetensors:  81% 4.02G/4.99G [01:32<00:23, 41.0MB/s]
# model-00001-of-00003.safetensors:  81% 4.03G/4.99G [01:33<00:46, 20.5MB/s]
#
# model-00002-of-00003.safetensors:  92% 4.57G/4.99G [01:33<00:18, 22.0MB/s]
# model-00001-of-00003.safetensors:  81% 4.04G/4.99G [01:33<00:35, 26.7MB/s]
#
# model-00002-of-00003.safetensors:  92% 4.58G/4.99G [01:33<00:14, 28.4MB/s]
#
# model-00002-of-00003.safetensors:  92% 4.60G/4.99G [01:33<00:08, 45.5MB/s]
# model-00001-of-00003.safetensors:  81% 4.06G/4.99G [01:33<00:22, 41.8MB/s]
#
# model-00002-of-00003.safetensors:  93% 4.62G/4.99G [01:34<00:05, 64.5MB/s]
# model-00001-of-00003.safetensors:  82% 4.08G/4.99G [01:34<00:15, 58.0MB/s]
#
# model-00002-of-00003.safetensors:  93% 4.65G/4.99G [01:34<00:04, 84.6MB/s]
#
# model-00002-of-00003.safetensors:  94% 4.68G/4.99G [01:34<00:02, 117MB/s]
# model-00001-of-00003.safetensors:  82% 4.09G/4.99G [01:34<00:17, 52.5MB/s]
#
# model-00002-of-00003.safetensors:  94% 4.71G/4.99G [01:34<00:02, 136MB/s]
# model-00001-of-00003.safetensors:  82% 4.10G/4.99G [01:34<00:17, 49.6MB/s]
#
# model-00002-of-00003.safetensors:  95% 4.73G/4.99G [01:34<00:02, 125MB/s]
# model-00001-of-00003.safetensors:  82% 4.11G/4.99G [01:34<00:18, 47.0MB/s]
#
# model-00002-of-00003.safetensors:  95% 4.75G/4.99G [01:38<00:14, 16.1MB/s]
#
# model-00002-of-00003.safetensors:  96% 4.77G/4.99G [01:39<00:12, 17.3MB/s]
#
# model-00002-of-00003.safetensors:  96% 4.80G/4.99G [01:40<00:06, 26.7MB/s]
# model-00001-of-00003.safetensors:  83% 4.12G/4.99G [01:40<02:07, 6.77MB/s]
#
# model-00002-of-00003.safetensors:  97% 4.82G/4.99G [01:40<00:04, 34.7MB/s]
# model-00001-of-00003.safetensors:  83% 4.13G/4.99G [01:40<01:35, 8.99MB/s]
#
# model-00002-of-00003.safetensors:  97% 4.84G/4.99G [01:40<00:03, 44.9MB/s]
#
# model-00002-of-00003.safetensors:  98% 4.87G/4.99G [01:40<00:02, 55.0MB/s]
# model-00001-of-00003.safetensors:  83% 4.15G/4.99G [01:40<00:55, 15.1MB/s]
# model-00001-of-00003.safetensors:  83% 4.16G/4.99G [01:40<00:43, 18.9MB/s]
#
# model-00002-of-00003.safetensors:  98% 4.89G/4.99G [01:40<00:01, 66.0MB/s]
# model-00001-of-00003.safetensors:  84% 4.18G/4.99G [01:40<00:27, 29.0MB/s]
#
# model-00002-of-00003.safetensors:  98% 4.91G/4.99G [01:40<00:00, 79.8MB/s]
# model-00001-of-00003.safetensors:  84% 4.20G/4.99G [01:40<00:19, 41.1MB/s]
# model-00001-of-00003.safetensors:  85% 4.23G/4.99G [01:40<00:13, 55.2MB/s]
#
# model-00002-of-00003.safetensors:  99% 4.93G/4.99G [01:41<00:00, 77.4MB/s]
# model-00001-of-00003.safetensors:  85% 4.25G/4.99G [01:41<00:11, 65.1MB/s]
#
# model-00002-of-00003.safetensors:  99% 4.95G/4.99G [01:41<00:00, 83.1MB/s]
#
# model-00002-of-00003.safetensors: 100% 4.97G/4.99G [01:41<00:00, 82.2MB/s]
#
# model-00002-of-00003.safetensors: 100% 4.99G/4.99G [01:41<00:00, 49.0MB/s]
#
# model-00001-of-00003.safetensors:  86% 4.27G/4.99G [01:41<00:13, 54.7MB/s]
# model-00001-of-00003.safetensors:  86% 4.28G/4.99G [01:41<00:13, 52.9MB/s]
# model-00001-of-00003.safetensors:  86% 4.29G/4.99G [01:42<00:13, 50.6MB/s]
# model-00001-of-00003.safetensors:  86% 4.30G/4.99G [01:42<00:14, 48.6MB/s]
# model-00001-of-00003.safetensors:  86% 4.31G/4.99G [01:42<00:14, 47.1MB/s]
# model-00001-of-00003.safetensors:  87% 4.32G/4.99G [01:42<00:14, 45.7MB/s]
# model-00001-of-00003.safetensors:  87% 4.33G/4.99G [01:43<00:14, 45.1MB/s]
# model-00001-of-00003.safetensors:  87% 4.34G/4.99G [01:43<00:14, 44.4MB/s]
# model-00001-of-00003.safetensors:  87% 4.35G/4.99G [01:43<00:14, 43.9MB/s]
# model-00001-of-00003.safetensors:  87% 4.36G/4.99G [01:43<00:14, 43.6MB/s]
# model-00001-of-00003.safetensors:  88% 4.37G/4.99G [01:44<00:14, 43.6MB/s]
# model-00001-of-00003.safetensors:  88% 4.38G/4.99G [01:44<00:13, 43.6MB/s]
# model-00001-of-00003.safetensors:  88% 4.39G/4.99G [01:44<00:13, 43.6MB/s]
# model-00001-of-00003.safetensors:  88% 4.40G/4.99G [01:44<00:13, 44.2MB/s]
# model-00001-of-00003.safetensors:  89% 4.41G/4.99G [01:45<00:12, 45.8MB/s]
# model-00001-of-00003.safetensors:  89% 4.42G/4.99G [01:45<00:12, 44.9MB/s]
# model-00001-of-00003.safetensors:  89% 4.44G/4.99G [01:45<00:12, 44.8MB/s]
# model-00001-of-00003.safetensors:  89% 4.45G/4.99G [01:45<00:11, 45.4MB/s]
# model-00001-of-00003.safetensors:  89% 4.46G/4.99G [01:45<00:11, 46.5MB/s]
# model-00001-of-00003.safetensors:  90% 4.47G/4.99G [01:46<00:11, 46.1MB/s]
# model-00001-of-00003.safetensors:  90% 4.48G/4.99G [01:46<00:10, 47.9MB/s]
# model-00001-of-00003.safetensors:  90% 4.49G/4.99G [01:46<00:10, 47.1MB/s]
# model-00001-of-00003.safetensors:  90% 4.50G/4.99G [01:46<00:09, 48.9MB/s]
# model-00001-of-00003.safetensors:  90% 4.51G/4.99G [01:47<00:10, 47.7MB/s]
# model-00001-of-00003.safetensors:  91% 4.52G/4.99G [01:47<00:09, 49.7MB/s]
# model-00001-of-00003.safetensors:  91% 4.53G/4.99G [01:47<00:09, 48.6MB/s]
# model-00001-of-00003.safetensors:  91% 4.54G/4.99G [01:47<00:08, 50.1MB/s]
# model-00001-of-00003.safetensors:  91% 4.55G/4.99G [01:47<00:08, 51.5MB/s]
# model-00001-of-00003.safetensors:  91% 4.56G/4.99G [01:48<00:08, 50.1MB/s]
# model-00001-of-00003.safetensors:  92% 4.57G/4.99G [01:48<00:08, 51.6MB/s]
# model-00001-of-00003.safetensors:  92% 4.58G/4.99G [01:48<00:07, 52.7MB/s]
# model-00001-of-00003.safetensors:  92% 4.59G/4.99G [01:48<00:07, 53.6MB/s]
# model-00001-of-00003.safetensors:  92% 4.60G/4.99G [01:48<00:07, 54.5MB/s]
# model-00001-of-00003.safetensors:  93% 4.61G/4.99G [01:49<00:06, 55.1MB/s]
# model-00001-of-00003.safetensors:  93% 4.62G/4.99G [01:49<00:06, 55.8MB/s]
# model-00001-of-00003.safetensors:  93% 4.63G/4.99G [01:49<00:06, 56.2MB/s]
# model-00001-of-00003.safetensors:  93% 4.65G/4.99G [01:49<00:06, 56.8MB/s]
# model-00001-of-00003.safetensors:  93% 4.66G/4.99G [01:49<00:05, 57.4MB/s]
# model-00001-of-00003.safetensors:  94% 4.67G/4.99G [01:49<00:05, 57.7MB/s]
# model-00001-of-00003.safetensors:  94% 4.68G/4.99G [01:50<00:05, 58.0MB/s]
# model-00001-of-00003.safetensors:  94% 4.69G/4.99G [01:50<00:05, 58.9MB/s]
# model-00001-of-00003.safetensors:  94% 4.70G/4.99G [01:50<00:04, 62.1MB/s]
# model-00001-of-00003.safetensors:  94% 4.71G/4.99G [01:50<00:04, 60.9MB/s]
# model-00001-of-00003.safetensors:  95% 4.72G/4.99G [01:50<00:04, 61.3MB/s]
# model-00001-of-00003.safetensors:  95% 4.73G/4.99G [01:50<00:04, 64.1MB/s]
# model-00001-of-00003.safetensors:  95% 4.74G/4.99G [01:51<00:03, 63.7MB/s]
# model-00001-of-00003.safetensors:  95% 4.75G/4.99G [01:51<00:03, 63.4MB/s]
# model-00001-of-00003.safetensors:  95% 4.76G/4.99G [01:51<00:03, 66.5MB/s]
# model-00001-of-00003.safetensors:  96% 4.77G/4.99G [01:51<00:03, 65.4MB/s]
# model-00001-of-00003.safetensors:  96% 4.78G/4.99G [01:51<00:03, 68.0MB/s]
# model-00001-of-00003.safetensors:  96% 4.79G/4.99G [01:51<00:02, 67.1MB/s]
# model-00001-of-00003.safetensors:  96% 4.80G/4.99G [01:52<00:02, 62.8MB/s]
# model-00001-of-00003.safetensors:  97% 4.82G/4.99G [01:52<00:02, 72.1MB/s]
# model-00001-of-00003.safetensors:  97% 4.83G/4.99G [01:52<00:02, 73.2MB/s]
# model-00001-of-00003.safetensors:  97% 4.84G/4.99G [01:52<00:01, 74.7MB/s]
# model-00001-of-00003.safetensors:  97% 4.85G/4.99G [01:52<00:01, 73.0MB/s]
# model-00001-of-00003.safetensors:  98% 4.87G/4.99G [01:52<00:01, 74.3MB/s]
# model-00001-of-00003.safetensors:  98% 4.88G/4.99G [01:52<00:01, 76.2MB/s]
# model-00001-of-00003.safetensors:  98% 4.89G/4.99G [01:53<00:01, 76.5MB/s]
# model-00001-of-00003.safetensors:  98% 4.90G/4.99G [01:53<00:01, 79.5MB/s]
# model-00001-of-00003.safetensors:  98% 4.91G/4.99G [01:53<00:01, 77.1MB/s]
# model-00001-of-00003.safetensors:  99% 4.92G/4.99G [01:53<00:00, 77.9MB/s]
# model-00001-of-00003.safetensors:  99% 4.93G/4.99G [01:53<00:00, 79.5MB/s]
# model-00001-of-00003.safetensors:  99% 4.94G/4.99G [01:53<00:00, 81.0MB/s]
# model-00001-of-00003.safetensors:  99% 4.95G/4.99G [01:53<00:00, 82.3MB/s]
# model-00001-of-00003.safetensors:  99% 4.96G/4.99G [01:54<00:00, 83.2MB/s]
# model-00001-of-00003.safetensors: 100% 4.97G/4.99G [01:54<00:00, 84.0MB/s]
# model-00001-of-00003.safetensors: 100% 4.99G/4.99G [01:54<00:00, 43.6MB/s]
# Fetching 3 files: 100% 3/3 [01:54<00:00, 38.19s/it]
# Loading checkpoint shards: 100% 3/3 [00:58<00:00, 19.46s/it]
# generation_config.json: 100% 154/154 [00:00<00:00, 951kB/s]
# tokenizer_config.json: 100% 39.9k/39.9k [00:00<00:00, 104MB/s]
# tokenizer.json: 100% 32.2M/32.2M [00:00<00:00, 61.7MB/s]
# special_tokens_map.json: 100% 4.23k/4.23k [00:00<00:00, 27.6MB/s]

# %%
mt_model_name = "kreasof-ai/nllb-200-distilled-600M-bem2en-flores200"
output_mt = "ct2-nllb-be-en-finetuned"
commit_hash = "b7ab3b4345d080c83dd98b9c51d970d8d27dd18b"
# !ct2-transformers-converter --model {mt_model_name} --revision {commit_hash} --quantization float16 --output_dir {output_mt} --force

# %%
# !wget https://s3.amazonaws.com/opennmt-models/nllb-200/flores200_sacrebleu_tokenizer_spm.model
# Out:
# --2025-04-17 02:49:24--  https://s3.amazonaws.com/opennmt-models/nllb-200/flores200_sacrebleu_tokenizer_spm.model
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.233.160, 52.217.134.144, 52.217.96.166, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.233.160|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4852054 (4.6M) [binary/octet-stream]
# Saving to: ‘flores200_sacrebleu_tokenizer_spm.model’
#
# flores200_sacrebleu 100%[===================>]   4.63M  9.35MB/s    in 0.5s
#
# 2025-04-17 02:49:25 (9.35 MB/s) - ‘flores200_sacrebleu_tokenizer_spm.model’ saved [4852054/4852054]

# %%
import os

directory = "/content/"

ct2_model_name = output_mt

ct_model_path = os.path.join(directory, ct2_model_name)
sp_model_path = os.path.join(directory, "flores200_sacrebleu_tokenizer_spm.model")

# %%
import ctranslate2
import sentencepiece as spm
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

sp = spm.SentencePieceProcessor()
sp.load(sp_model_path)

translator = ctranslate2.Translator(ct_model_path, device=device)

# %%
# Translate

# src_lang = "ben_Beng"
# tgt_lang = "eng_Latn"

src_lang = "bem_Latn"
tgt_lang = "eng_Latn"

beam_size = 5

source_sents = [sent.strip() for sent in source_sentences]
target_prefix = [[tgt_lang]] * len(source_sents)

# Subword the source sentences
source_sents_subworded = sp.encode_as_pieces(source_sents)
source_sents_subworded = [[src_lang] + sent + ["</s>"] for sent in source_sents_subworded]

# Translate the source sentences
translations = translator.translate_batch(source_sents_subworded,
                                          batch_type="tokens",
                                          max_batch_size=2024,
                                          beam_size=beam_size,
                                          target_prefix=target_prefix)
translations = [translation.hypotheses[0] for translation in translations]

# Desubword the target sentences
translations_desubword = sp.decode(translations)
translations_desubword = [sent[len(tgt_lang):].strip() for sent in translations_desubword]

print(*translations_desubword[:10], sep="\n")
# Out:
# "We now have a 4-month gestation period for those who do not have pre-existing diabetes," he added.
# Doctor Ehud Ur, professor of medicine at Dalhousie University in Halifax, Nova Scotia and chairman of the Canadian Diabetes Association's department of hospitals and medicine, issued a warning that the investigation is still in its early stages.
# Like other medical personnel, they are also wondering whether diabetes can be cured, not knowing that findings from the study have no effect on people already with Type 1 diabetes.
# On Monday, Sara Danius, co-author of the Nobel Committee for Literature at the Swedish Academy, announced via a press conference in Sweden's Sveriges Radio that the organisation, having failed to reach Bob Dylan as the winner of the 2016 Nobel Prize in Literature, was protesting by trying to reach him.
# Danius said, "We're not doing anything at the moment. We've sent phones and emails to the nearby moderator and received very peaceful responses. For now, that's fine."
# Earlier in the day, Ring's boss, Jamie Siminoff, said his company started when his door bell could barely be heard from his shop in his garage.
# He made a WiFi door mat, that's what he said.
# Siminoff said that the sale had been hampered by his 2013 exposure in the Shark Tank news and the media had to pay him a starting fee.
# In late 2017, Siminoff appeared on the commercial TV channel QVC.
# The Ring team also settled a lawsuit with the security company it was competing with, ADT Corporation.

# %%
# translations_desubword

# %%
lst_data = [{"src": src, "mt":mt, "ref":ref} for src, mt, ref in zip(source_sentences, translations_desubword, references)]

# %%
lst_data[:2]
# Out:
# [{'src': '“Natukwata nomba ba kwindi abali ne myeshi 4 abo pali ino nshita abashikwete ubulwele bwa dayabetisi ubo bakwete kale,” efyo balundilepo.',
#   'mt': '"We now have a 4-month gestation period for those who do not have pre-existing diabetes," he added.',
#   'ref': '"We now have 4-month-old mice that are non-diabetic that used to be diabetic," he added.'},
#  {'src': 'Bashing’anga ba Ehud Ur, ba pulofesa bafya miti pe sukulu likalamba ilya Dalhousie University mu Halifax, Nova Scotia kabili abakumupando mu ciputulwa ca fipatala ne miti mu kabungwe ka Canadian Diabetes Association bapeele ubusoko bwakuti ukufwailisha kucili munshiku shakutendekela.',
#   'mt': "Doctor Ehud Ur, professor of medicine at Dalhousie University in Halifax, Nova Scotia and chairman of the Canadian Diabetes Association's department of hospitals and medicine, issued a warning that the investigation is still in its early stages.",
#   'ref': 'Dr. Ehud Ur, professor of medicine at Dalhousie University in Halifax, Nova Scotia and chair of the clinical and scientific division of the Canadian Diabetes Association cautioned that the research is still in its early days.'}]

# %%
len(lst_data)
# Out:
# 1012

# %%
from comet import download_model, load_from_checkpoint

# %%
model_path = download_model("masakhane/africomet-mtl")
model = load_from_checkpoint(model_path)
# data = [
#     {
#         "src": "Pali Cimo, abasayanshi ukufuma pe sukulu lya Stanford University School of Medicine babilishe ukupangwa kwa kabombelo kakupimina akapya akengasobolola insandesande mu misango yashiko; akantu kamo akanono akengapulintwa elyo akengapangwa ukubomfya amapulinta ya inkjet pa mutengo wa U.S cent imo cilakamo.",
#         "mt": "On Monday, scientists from the Stanford University School of Medicine announced the invention of a new diagnostic tool that can sort cells; a smaller one that can be printed and manufactured using an inkjet printer for about one U.S. cent each.",
#         "ref": "On Monday, scientists from the Stanford University School of Medicine announced the invention of a new diagnostic tool that can sort cells by type: a tiny printable chip that can be manufactured using standard inkjet printers for possibly about one U.S. cent each."
#     },
#     {
#         "src": "Kensha wa ndeke aishibikwe nge ntungulushi ya Squadron Dilokrit Pattavee.",
#         "mt": "The pilot was identified as Squadron Leader Dilokrit Pattavee.",
#         "ref": "The pilot was identified as Squadron Leader Dilokrit Pattavee."
#     }
# ]
data = lst_data
model_output = model.predict(data, batch_size=8, gpus=1)
print (model_output)
# Out:
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model.ckpt:   0%|          | 0.00/2.26G [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/2.42k [00:00<?, ?B/s]
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# hparams.yaml:   0%|          | 0.00/715 [00:00<?, ?B/s]
# INFO:pytorch_lightning.utilities.migration.utils:Lightning automatically upgraded your loaded checkpoint from v1.9.5 to v2.5.1. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../root/.cache/huggingface/hub/models--masakhane--africomet-mtl/snapshots/c00016e2a120e8583b36c602d7be69ba1b45f088/checkpoints/model.ckpt`
# tokenizer_config.json:   0%|          | 0.00/399 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/714 [00:00<?, ?B/s]
# INFO:pytorch_lightning.utilities.rank_zero:You are using the plain ModelCheckpoint callback. Consider using LitModelCheckpoint which with seamless uploading to Model registry.
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Predicting DataLoader 0: 100%|██████████| 127/127 [01:09<00:00,  1.84it/s]
# Prediction([('scores', [0.5023051500320435, 0.6403608322143555, 0.6419937014579773, 0.45627591013908386, 0.6652087569236755, 0.6170231103897095, 0.30913588404655457, 0.36161625385284424, 0.7363357543945312, 0.7301385402679443, 0.6960641741752625, 0.6450138092041016, 0.516394317150116, 0.6874213218688965, 0.5114876627922058, 0.5437520742416382, 0.6600040793418884, 0.7138833999633789, 0.5087156891822815, 0.6847285628318787, 0.5658583045005798, 0.4549867510795593, -0.05183158814907074, 0.5459262728691101, 0.7201809883117676, 0.7735568881034851, 0.5938011407852173, 0.446958065032959, 0.5518287420272827, 0.588054358959198, 0.4477892518043518, 0.38218483328819275, 0.4968201518058777, 0.7271654605865479, 0.7898964881896973, 0.7388176321983337, 0.5794627070426941, 0.2047790288925171, 0.6447727680206299, 0.7553180456161499, 0.49521276354789734, 0.7968459129333496, 0.6392634510993958, 0.7313911318778992, 0.6658910512924194, 0.6163769960403442, 0.7042516469955444, 0.5710843801498413, 0.526150107383728, 0.60005122423172, 0.42051011323928833, 0.5145047903060913, 0.4417654871940613, 0.5334100127220154, 0.5628032684326172, 0.634238064289093, 0.6577694416046143, 0.6667708158493042, 0.6266359090805054, 0.752762496471405, 0.6645179986953735, 0.5969398617744446, 0.7094964385032654, 0.40553268790245056, 0.6026952266693115, 0.5399262309074402, 0.5463626980781555, 0.40863120555877686, 0.7073873281478882, 0.6433489322662354, 0.48915061354637146, 0.6407720446586609, 0.5889043211936951, 0.594923734664917, 0.6618690490722656, 0.588103711605072, 0.6540576815605164, 0.6741049289703369, 0.7838082313537598, 0.7184659242630005, 0.7065207362174988, 0.705439031124115, 0.6534219980239868, 0.39033958315849304, 0.597030520439148, 0.6918694972991943, 0.5962836742401123, 0.3218020796775818, 0.6219360828399658, 0.42902421951293945, 0.5789550542831421, 0.6588263511657715, 0.6349976062774658, 0.6804863810539246, 0.6445978879928589, 0.6949737071990967, 0.5820406079292297, 0.7400221228599548, 0.6636603474617004, 0.6477188467979431, 0.7300399541854858, 0.7130412459373474, 0.7169284224510193, 0.7305442094802856, 0.6199854612350464, 0.6314983367919922, 0.4909467399120331, 0.6312596201896667, 0.6126664876937866, 0.6184726357460022, 0.6441245079040527, 0.3395695686340332, 0.739102303981781, 0.5979506969451904, 0.5884429216384888, 0.4839446246623993, 0.630412220954895, 0.5344066619873047, 0.6275472044944763, 0.500843346118927, 0.6160941123962402, 0.5705770254135132, 0.7521557807922363, 0.7290754318237305, 0.6695547103881836, 0.7429044246673584, 0.6899886131286621, 0.6273620128631592, 0.692956805229187, 0.6119747161865234, 0.5389757752418518, 0.6037397384643555, 0.6738840937614441, 0.6591122150421143, 0.5335084199905396, 0.21727292239665985, 0.7139863967895508, 0.5485402941703796, 0.6495832800865173, 0.6586918830871582, 0.4540267586708069, 0.6086949110031128, 0.6656230688095093, 0.4336404800415039, 0.5451948046684265, 0.6307926177978516, 0.688086211681366, 0.7073179483413696, 0.5424457788467407, 0.6439080238342285, 0.6562252640724182, 0.5604889392852783, 0.5879416465759277, 0.6924352049827576, 0.36965858936309814, 0.5734342336654663, 0.5825726985931396, 0.6384877562522888, 0.6484703421592712, 0.270545095205307, 0.6920487284660339, 0.5323119163513184, 0.6829671859741211, 0.6929096579551697, 0.686251163482666, 0.5596253275871277, 0.48738688230514526, 0.7054837942123413, 0.6155627965927124, 0.5736287832260132, 0.4646596908569336, 0.671670138835907, 0.30231887102127075, 0.616828441619873, 0.5758051872253418, 0.6569668054580688, 0.7284080982208252, 0.4591014087200165, 0.5667312741279602, 0.6686336994171143, 0.7077178955078125, 0.7544907331466675, 0.7476279139518738, 0.7574653625488281, 0.3543491065502167, 0.7821349501609802, 0.7391407489776611, 0.7223464250564575, 0.6394771933555603, 0.46523818373680115, 0.5260967016220093, 0.5828148722648621, 0.603757381439209, 0.6636817455291748, 0.3990255296230316, 0.7610933184623718, 0.5961331725120544, 0.5423717498779297, 0.6562318801879883,  ...

# %%
sys_score = model_output["system_score"]

# %%
print("COMET:", round(sys_score*100, 2))
# Out:
# COMET: 58.6

# %%
sys_score
# Out:
# 0.5859615388786487

# %%
0.5829142446651789 >0.5828630467324625
# Out:
# True
